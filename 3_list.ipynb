# %% [markdown]
# - List:
#     - it is constructed with [ ] brackets , and each item/ element separated by commas

# %%
my_ls=[True,False,"amar","khan",2,5,9,3.14,8+8j]

my_ls
# Out:
# [True, False, 'amar', 'khan', 2, 5, 9, 3.14, (8+8j)]

# %% [markdown]
# -  +ve & - ve index

# %%
my_ls[2]
# Out:
# 'amar'

# %%
my_ls[-1]
# Out:
# (8+8j)

# %%
my_ls[-5]
# Out:
# 2

# %%
metrics=["accuracy","precision","recall","auc_roc_score","F1score",True,3.14,11.22,6+9j]

# %%
metrics
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'auc_roc_score',
#  'F1score',
#  True,
#  3.14,
#  11.22,
#  (6+9j)]

# %%
# grab the 1st item

metrics[0]
# Out:
# 'accuracy'

# %%
# grab the second item from the -ve index

metrics[-2]
# Out:
# 11.22

# %%
metrics[1]
# Out:
# 'precision'

# %%
metrics[1][1]
# Out:
# 'r'

# %%
metrics[1][0::2]
# Out:
# 'peiin'

# %% [markdown]
# - slicing

# %% [markdown]
# - +ve & -ve

# %%
metrics
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'auc_roc_score',
#  'F1score',
#  True,
#  3.14,
#  11.22,
#  (6+9j)]

# %%
metrics[0:3]
# Out:
# ['accuracy', 'precision', 'recall']

# %%
metrics[2:5]
# Out:
# ['recall', 'auc_roc_score', 'F1score']

# %%
metrics
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'auc_roc_score',
#  'F1score',
#  True,
#  3.14,
#  11.22,
#  (6+9j)]

# %%
metrics[2::2]
# Out:
# ['recall', 'F1score', 3.14, (6+9j)]

# %%
metrics[::-2]
# Out:
# [(6+9j), 3.14, 'F1score', 'recall', 'accuracy']

# %%
metrics[2:6:-2]
# Out:
# []

# %%
metrics[-9:]
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'auc_roc_score',
#  'F1score',
#  True,
#  3.14,
#  11.22,
#  (6+9j)]

# %%
metrics[-9:9]
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'auc_roc_score',
#  'F1score',
#  True,
#  3.14,
#  11.22,
#  (6+9j)]

# %%
metrics[-9:-1]
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'auc_roc_score',
#  'F1score',
#  True,
#  3.14,
#  11.22]

# %%
metrics[-9:-1:]
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'auc_roc_score',
#  'F1score',
#  True,
#  3.14,
#  11.22]

# %%
metrics[-9:-1:1]
# Out:
# ['accuracy',
#  'precision',
#  'recall',
#  'auc_roc_score',
#  'F1score',
#  True,
#  3.14,
#  11.22]

# %%
metrics[-9:-1:-1]
# Out:
# []

# %%
metrics[-9:-1:2]
# Out:
# ['accuracy', 'recall', 'F1score', 3.14]

# %% [markdown]
# - Functions

# %% [markdown]
# - len()

# %%
a="afiz khan"

print(a)

print(len(a))
# Out:
# afiz khan
# 9

# %%
my_ls=[True,False,"amar","khan",2,5,9,3.14,8+8j,3.5]


len(my_ls)
# Out:
# 10

# %% [markdown]
# - Min()/ Max()/ Sum()

# %%
x=[1,2,39,99,67,89,3,0,99,104,101]


x
# Out:
# [1, 2, 39, 99, 67, 89, 3, 0, 99, 104, 101]

# %%
min(x)
# Out:
# 0

# %%
max(x)
# Out:
# 104

# %%
sum(x)
# Out:
# 604

# %%
y=["a","b","z","y","m"]

print(min(y))

print(max(y))
# Out:
# a
# z

# %%
z=["a","b","z","y","m","B","Y"]

print(min(z))

print(max(z))
# Out:
# B
# z

# %% [markdown]
# - sorted()

# %%
x=[1,2,39,99,67,89,3,0,99,104,101]

sorted(x)
# Out:
# [0, 1, 2, 3, 39, 67, 89, 99, 99, 101, 104]

# %%
sorted(x,reverse=True)
# Out:
# [104, 101, 99, 99, 89, 67, 39, 3, 2, 1, 0]

# %% [markdown]
# - method

# %% [markdown]
# list are mutable

# %% [markdown]
# - append / extend / insert

# %%
x=[1,2,39,99,67,89,3,0,99,104,101]

# %%
x.append(1000)

# %%
x
# Out:
# [1, 2, 39, 99, 67, 89, 3, 0, 99, 104, 101, 1000]

# %%
x
# Out:
# [1, 2, 39, 99, 67, 89, 3, 0, 99, 104, 101, 1000]

# %%
x
# Out:
# [1, 2, 39, 99, 67, 89, 3, 0, 99, 104, 101, 1000]

# %%
x=[1,2,39,99,67,89,3,0,99,104,101]


x.extend(["afiz khan","ganesh","amar"])

# %%
x
# Out:
# [1, 2, 39, 99, 67, 89, 3, 0, 99, 104, 101, 'afiz khan', 'ganesh', 'amar']

# %%
x.insert(0,"clri")

# %%
x
# Out:
# ['clri',
#  1,
#  2,
#  39,
#  99,
#  67,
#  89,
#  3,
#  0,
#  99,
#  104,
#  101,
#  'afiz khan',
#  'ganesh',
#  'amar']

# %%
x.insert(2,"ravi")

# %%
x
# Out:
# ['clri',
#  1,
#  'ravi',
#  2,
#  39,
#  99,
#  67,
#  89,
#  3,
#  0,
#  99,
#  104,
#  101,
#  'afiz khan',
#  'ganesh',
#  'amar']

# %% [markdown]
# - pop / remove / clear

# %%
x
# Out:
# ['clri',
#  1,
#  'ravi',
#  2,
#  39,
#  99,
#  67,
#  89,
#  3,
#  0,
#  99,
#  104,
#  101,
#  'afiz khan',
#  'ganesh',
#  'amar']

# %%
x.pop()
# Out:
# 'amar'

# %%
x
# Out:
# ['clri',
#  1,
#  'ravi',
#  2,
#  39,
#  99,
#  67,
#  89,
#  3,
#  0,
#  99,
#  104,
#  101,
#  'afiz khan',
#  'ganesh']

# %%
x.pop(0)
# Out:
# 'clri'

# %%
x
# Out:
# [1, 'ravi', 2, 39, 99, 67, 89, 3, 0, 99, 104, 101, 'afiz khan', 'ganesh']

# %%
x.remove("ravi")

# %%
x
# Out:
# [1, 2, 39, 99, 67, 89, 3, 0, 99, 104, 101, 'afiz khan', 'ganesh']

# %%
x.remove(104)

# %%
x
# Out:
# [1, 2, 39, 99, 67, 89, 3, 0, 99, 101, 'afiz khan', 'ganesh']

# %%
a=[1,"r",3,4,5]


del a[2]

# %%
a
# Out:
# [1, 'r', 4, 5]

# %%
b=[1,"r",3,4,5]

b.clear()

# %%
b
# Out:
# []

# %%
a=[1,"r",3,4,5]


del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined
