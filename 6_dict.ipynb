# %% [markdown]
# # - Dictionary
#    - Mapping of one to one relationship between **key , value** pair is called dict
#
#    - what is mapping ?
#        - collection of objects
#
#    - A dictinary object is constructed using curly braces { key1 : value1 , key2:value2 }

# %%
marvel_dict={"Name":"thor","place":"asgard","weapon":"Hammer","super_heros":["ironman","capitan america"] }

# %%
marvel_dict
# Out:
# {'Name': 'thor',
#  'place': 'asgard',
#  'weapon': 'Hammer',
#  'super_heros': ['ironman', 'capitan america']}

# %%
marvel_dict["Name"]
# Out:
# 'thor'

# %%
marvel_dict["weapon"]
# Out:
# 'Hammer'

# %%
type(marvel_dict)
# Out:
# dict

# %% [markdown]
# - methods

# %% [markdown]
# - **keys()**
#    - it returns the list of keys in the dict object

# %%
marvel_dict.keys()
# Out:
# dict_keys(['Name', 'place', 'weapon', 'super_heros'])

# %%
list(marvel_dict.keys())
# Out:
# ['Name', 'place', 'weapon', 'super_heros']

# %%
tuple(marvel_dict.keys())
# Out:
# ('Name', 'place', 'weapon', 'super_heros')

# %% [markdown]
# - **values()**

# %%
marvel_dict
# Out:
# {'Name': 'thor',
#  'place': 'asgard',
#  'weapon': 'Hammer',
#  'super_heros': ['ironman', 'capitan america']}

# %%
marvel_dict.values()
# Out:
# dict_values(['thor', 'asgard', 'Hammer', ['ironman', 'capitan america']])

# %%
list(marvel_dict.values())
# Out:
# ['thor', 'asgard', 'Hammer', ['ironman', 'capitan america']]

# %%
tuple(marvel_dict.values())
# Out:
# ('thor', 'asgard', 'Hammer', ['ironman', 'capitan america'])

# %% [markdown]
# - **items()**
#
#    - it returns the list of keys & values

# %%
marvel_dict.items()
# Out:
# dict_items([('Name', 'thor'), ('place', 'asgard'), ('weapon', 'Hammer'), ('super_heros', ['ironman', 'capitan america'])])

# %%
list(marvel_dict.items())
# Out:
# [('Name', 'thor'),
#  ('place', 'asgard'),
#  ('weapon', 'Hammer'),
#  ('super_heros', ['ironman', 'capitan america'])]

# %% [markdown]
# - get()

# %%
marvel_dict.get("place")
# Out:
# 'asgard'

# %%
marvel_dict.get("play")

# %%
marvel_dict.get("place","it was not found")
# Out:
# 'asgard'

# %%
marvel_dict.get("play","it was not found")
# Out:
# 'it was not found'

# %%
marvel_dict
# Out:
# {'Name': 'thor',
#  'place': 'asgard',
#  'weapon': 'Hammer',
#  'super_heros': ['ironman', 'capitan america']}

# %%
# add new item
marvel_dict["afiz khan"]="student"

# %%
marvel_dict
# Out:
# {'Name': 'thor',
#  'place': 'asgard',
#  'weapon': 'Hammer',
#  'super_heros': ['ironman', 'capitan america'],
#  'afiz khan': 'student'}

# %% [markdown]
# - update()

# %%
marvel_dict.update({"ganesh":"student","amar":"student"})

# %%
marvel_dict
# Out:
# {'Name': 'thor',
#  'place': 'asgard',
#  'weapon': 'Hammer',
#  'super_heros': ['ironman', 'capitan america'],
#  'afiz khan': 'student',
#  'ganesh': 'student',
#  'amar': 'student'}

# %%
len(marvel_dict)
# Out:
# 7

# %% [markdown]
# - copy()

# %%
d1={"name":"afiz","B.COM":["PYTHON","SQL","Six sigma","Lean","manual testing","Dataanalytics","statistics","excel","tableau","powerbi"]}

# %%
d1
# Out:
# {'name': 'afiz',
#  'B.COM': ['PYTHON',
#   'SQL',
#   'Six sigma',
#   'Lean',
#   'manual testing',
#   'Dataanalytics',
#   'statistics',
#   'excel',
#   'tableau',
#   'powerbi']}

# %%
d2=d1.copy()

# %%
d2
# Out:
# {'name': 'afiz',
#  'B.COM': ['PYTHON',
#   'SQL',
#   'Six sigma',
#   'Lean',
#   'manual testing',
#   'Dataanalytics',
#   'statistics',
#   'excel',
#   'tableau',
#   'powerbi']}

# %%
del d1["name"]

# %%
d1
# Out:
# {'B.COM': ['PYTHON',
#   'SQL',
#   'Six sigma',
#   'Lean',
#   'manual testing',
#   'Dataanalytics',
#   'statistics',
#   'excel',
#   'tableau',
#   'powerbi']}

# %%
d2
# Out:
# {'name': 'afiz',
#  'B.COM': ['PYTHON',
#   'SQL',
#   'Six sigma',
#   'Lean',
#   'manual testing',
#   'Dataanalytics',
#   'statistics',
#   'excel',
#   'tableau',
#   'powerbi']}

# %%
d2.pop("name")
# Out:
# 'afiz'

# %%
d2
# Out:
# {'B.COM': ['PYTHON',
#   'SQL',
#   'Six sigma',
#   'Lean',
#   'manual testing',
#   'Dataanalytics',
#   'statistics',
#   'excel',
#   'tableau',
#   'powerbi']}

# %% [markdown]
# updating key

# %%
d2
# Out:
# {'B.COM': ['PYTHON',
#   'SQL',
#   'Six sigma',
#   'Lean',
#   'manual testing',
#   'Dataanalytics',
#   'statistics',
#   'excel',
#   'tableau',
#   'powerbi']}

# %%
d2["Skills"]=d2.pop("B.COM")

# %%
d2
# Out:
# {'Skills': ['PYTHON',
#   'SQL',
#   'Six sigma',
#   'Lean',
#   'manual testing',
#   'Dataanalytics',
#   'statistics',
#   'excel',
#   'tableau',
#   'powerbi']}

# %%
d1
# Out:
# {'B.COM': ['PYTHON',
#   'SQL',
#   'Six sigma',
#   'Lean',
#   'manual testing',
#   'Dataanalytics',
#   'statistics',
#   'excel',
#   'tableau',
#   'powerbi']}

# %%
d1.clear()

# %%
d1
# Out:
# {}

# %%
del d2

# %%
d2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 d2
#
# NameError: name 'd2' is not defined

# %%
a1=[3]

a2=[4]

a3=[5]

nested_list=[a1,a2,a3]


nested_list
# Out:
# [[3], [4], [5]]
