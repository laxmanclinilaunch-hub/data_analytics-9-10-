# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **Pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with structured (tabular, multidimensional, potentially heterogeneous) and time series data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python.**

# %% [markdown]
# ### <b>Pandas</b> is designed to make it easier to work with structured data. Most of the analyses you might perform will likely involve using tabular data, e.g., from .csv files or relational databases (e.g., SQL). The DataFrame object in pandas is "a two-dimensional tabular, column-oriented data structure with both row and column labels."
#
# ### Here are just a few of the things that pandas does well:
#
# * #### Robust IO tools for loading data from flat files (CSV and delimited), Excel files, databases,
# * #### Easy handling of missing data (represented as NaN) in floating point as well as non-floating point data
# * #### Size mutability: columns can be inserted and deleted from DataFrame and higher dimensional objects
# * #### Automatic and explicit data alignment: objects can be explicitly aligned to a set of labels, or the user can simply ignore the labels and let Series, DataFrame, etc. automatically align the data for you in computations
# * #### Powerful, flexible group by functionality to perform split-apply-combine operations on data sets, for both aggregating and transforming data
# * #### Make it easy to convert ragged, differently-indexed data in other Python and NumPy data structures into DataFrame objects
# * #### Intelligent label-based slicing, fancy indexing, and subsetting of large data sets
# * #### Intuitive merging and joining data sets
# * #### Flexible reshaping and pivoting of data sets
# * #### Hierarchical labeling of axes (possible to have multiple labels per tick)
# * #### Time series-specific functionality: date range generation and frequency conversion, moving window statistics, moving window linear regressions, date shifting and lagging, etc.

# %% [markdown]
# ### <u>If you're curious:</u>
#
# #### The pandas name itself is derived from panel data, an econometrics term for multidimensional structured data sets, and Python data analysis itself. After getting introduced, you can consult the full pandas documentation.
# https://pandas.pydata.org/pandas-docs/stable/?v=20190919220335
#
# #### Pandas Cheatsheet: https://assets.datacamp.com/blog_assets/PandasPythonForDataScience.pdf

# %%
#Import package
import pandas as pd
import numpy as np

# %%
# Version of pandas
pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# There are two central concepts which you should know about:
#
# Series :
#  A series is essentially a column
#
# Data Frame :
# A DataFrame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. Pandas DataFrame consists of three principal components, the data, rows, and columns.

# %% [markdown]
# ![DataFrame 1.PNG](data:image/png;base64,...)

# %% [markdown]
# ## <b>Let us go ahead and create our first Pandas Series</b>

# %%
import pandas as pd

# %%
# Our first series
number_series = pd.Series([2, 3, 5, 6, 8])
print(number_series)
# Out:
# 0    2
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
print(number_series[0])
# Out:
# 2

# %%
print(number_series[4])
# Out:
# 8

# %%
# Same series but with different indices
number_series = pd.Series([2, 3, 5, 6, 8],index=['a', 'b', 'd','e','f'],name='Number')
print(number_series)
# Out:
# a    2
# b    3
# d    5
# e    6
# f    8
# Name: Number, dtype: int64

# %%
print(number_series['a'])
# Out:
# 2

# %% [markdown]
# ## <b>Let us go ahead and create our first Pandas DataFrame</b>

# %% [markdown]
# ### Using a 2-D NumPy array

# %%
# Creating our first DataFrame
some_2D_array = np.random.randint(4, 6,(3,4))
first_dataframe = pd.DataFrame(some_2D_array , columns=["pratik","likith","arunachalam","Divya"])
first_dataframe
# Out:
#    pratik  likith  arunachalam  Divya
# 0       5       5            4      4
# 1       5       5            4      5
# 2       5       5            5      5

# %%
# Lets create the same dataframe but different indices
another_dataframe = pd.DataFrame(some_2D_array, columns=["pratik","likith","arunachalam","Divya"],index = ['First','Second','Third'])
another_dataframe
# Out:
#         pratik  likith  arunachalam  Divya
# First        5       5            4      4
# Second       5       5            4      5
# Third        5       5            5      5

# %% [markdown]
# ## Using a conventional list of lists

# %%
# Initialize list of lists
list_of_lists = [  ['Amar', 10], ['Akbar', 15], ['Anthony', 14]   ]

# Create the pandas DataFrame
df = pd.DataFrame(list_of_lists, columns = ['Name', 'Age'])

# Print dataframe
df
# Out:
#       Name  Age
# 0     Amar   10
# 1    Akbar   15
# 2  Anthony   14

# %% [markdown]
# ## Using a dictionary

# %%
# Store the data in a dictionary
employee_dict = {'Employee Name':['Rajeev', 'Sumit', 'rithik'], 'Income':[200000, 140000, 90000]}

# Create DataFrame
employee_df = pd.DataFrame(employee_dict)

# Print the dataframe
employee_df
# Out:
#   Employee Name  Income
# 0        Rajeev  200000
# 1         Sumit  140000
# 2        rithik   90000

# %%
# Store the data in a dictionary
series_dict = {'First Series' : pd.Series([10, 20, 30, 40]),
              'Second Series' : pd.Series([10, 20, 30, 50])}

# Create the Dataframe using the dictionary
df = pd.DataFrame(series_dict)

# Print the dataframe
df
# Out:
#    First Series  Second Series
# 0            10             10
# 1            20             20
# 2            30             30
# 3            40             50

# %% [markdown]
# ## Using a list of dictionaries

# %%
# Initialise the list of dictionaries
list_of_dicts = [  {'a': 1, 'b': 2, 'c':3}, {'a':10, 'b': 20, 'c': 30}  ]  

# Create the DataFrame
df = pd.DataFrame(list_of_dicts)

# Print the dataframe
df
# Out:
#     a   b   c
# 0   1   2   3
# 1  10  20  30

# %%
# What happens if the number of keys are different in the two dictionaries
list_of_dicts = [{'a': 2, 'c':3}, {'a': 10, 'b': 20, 'c': 30}]
df = pd.DataFrame(list_of_dicts, index =['first', 'second'])
df
# Out:
#          a   c     b
# first    2   3   NaN
# second  10  30  20.0

# %%
# What happens if the number of keys are different in the two dictionaries
list_of_dicts = [{'a': 2, "b":np.nan,  'c':3}, {'a': 10, 'b': 20, 'c': 30}]
df = pd.DataFrame(list_of_dicts, index =['first', 'second'])
df
# Out:
#          a     b   c
# first    2   NaN   3
# second  10  20.0  30

# %% [markdown]
# ### There are other ways too!

# %%
# List of names
actor_names = ['Ryan Reynolds', 'Benedict Cumberbatch', 'Robert Downey Jr.', 'Chris Evans']

# List of their ages
actor_ages = [48,62,54,np.nan]

# Get the list of tuples by zipping the two lists together
list_of_tuples = list(zip(actor_names, actor_ages))

# Converting the list of tuples into pandas Dataframe
actor_df = pd.DataFrame(list_of_tuples, columns = ['Name', 'Age'])

# Print the dataframe
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  62.0
# 2     Robert Downey Jr.  54.0
# 3           Chris Evans   NaN

# %% [markdown]
# ## <b>So we have seen a variety of ways in which we can create simple dataframes. Now let us explore few methods and attributes associated with the pandas dataframes in Python</b>

# %% [markdown]
# ### We can print the indices of our dataframe using the <code>index</code> attribute

# %%
list(actor_df.index)
# Out:
# [0, 1, 2, 3]

# %%
actor_df.columns
# Out:
# Index(['Name', 'Age'], dtype='str')

# %% [markdown]
# ### Let us create a dataframe with 100 rows and 5 columns

# %%
np.random.randn(100,5) # range -3 to +3
# Out:
# array([[-1.06972372e+00,  7.03226408e-01, -9.25902298e-01,
#         -1.98084043e-01,  8.16872365e-01],
#        [ 4.59510455e-02,  2.50780904e+00,  3.63064664e-01,
#         -2.11794137e-02, -8.33638603e-01],
#        [-2.14580184e+00, -7.72772979e-01, -3.67456596e-01,
#         -3.40924840e-01, -7.39589257e-01],
#        [-1.31111384e+00, -1.15470054e-01, -1.08496332e+00,
#         -1.70010095e+00,  8.87513772e-02],
#        [ 6.22585413e-01,  1.52699029e-01, -6.68827696e-01,
#          2.66466083e-01,  1.56901450e+00],
#        [ 2.45768497e+00, -8.25939822e-01,  1.79050038e+00,
#          6.19448105e-01,  1.81682048e+00],
#        [ 2.04137976e+00,  4.07822825e-01, -2.90602892e-01,
#          4.06610579e-01, -2.55973339e+00],
#        [ 5.99459455e-01, -3.34659089e+00,  2.72894812e-01,
#          1.56183718e+00,  6.23652763e-01],
#         -1.16253918e+00,  2.44881598e-01],
#        [-1.03114570e+00,  6.06974393e-01,  8.29326577e-01,
#         -6.41587814e-01, -3.04525423e-01],
#        [ 1.15706761e-01,  1.59643774e+00,  1.27874386e+00,
#         -1.20892923e+00, -6.07068402e-01],
#        [-7.37620891e-01,  7.15810746e-01, -1.86488203e-01,
#         -6.18019062e-01,  9.57618243e-01],
#        [ 1.27129865e+00,  2.68882971e-02, -5.62186895e-01,
#          5.79055278e-01, -7.88252058e-01],
#        [ 4.21197638e-01,  2.52040209e-01,  7.18285709e-01,
#         -5.16198247e-01,  4.29810124e-01],
#        [ 1.22952801e-01, -2.48901357e-01,  8.03724002e-02,
#          3.21294744e-01,  2.03157741e+00],
#        [ 2.42549803e-01,  5.99145176e-01, -1.19554812e+00,
#          8.46117964e-02,  1.35575825e-01]])

# %%
np.random.randint(1, 500,(3,4))
# Out:
# array([[317, 472, 102, 423],
#        [379, 159,  44,  58],
#        [472, 414, 146, 268]], dtype=int32)

# %%
import pandas as pd
import numpy as np

# %%
# Create an array of shape (100,5)
our_array = np.random.randn(100, 5)
df = pd.DataFrame(our_array, columns=['A','B','C','D','E'])
df
# Out:
#            A         B         C         D         E
# 0  -0.154264 -0.669409  0.246002  0.077041  0.901568
# 1  -0.630891  0.277553  0.046143 -0.809495 -0.274543
# 2  -0.008714 -1.661417 -1.141469  1.327418 -1.847111
# 3  -1.319035 -0.730936  0.538331 -0.184677  1.092977
# 4  -0.979346  0.016180  0.036878 -2.126047 -0.087363
# ..       ...       ...       ...       ...       ...
# 95  1.437503  1.803351 -0.057762 -1.873986 -0.277288
# 96  1.183045 -1.489355 -0.056778  0.230856  1.064244
# 97 -1.003252  1.364895  0.358077 -0.081595  1.076395
# 98 -1.365442 -2.000331  0.437474  0.449832 -2.209277
# 99 -0.578452 -1.168125 -0.788659  1.094292 -0.600941
#
# [100 rows x 5 columns]

# %% [markdown]
# * ## <b><code>head()</code></b>
#
# #### Prints the first $n$ rows of the dataframe. By default it prints the first 5 rows

# %%
# We can use the head() method
df.head()
# Out:
#           A         B         C         D         E
# 0 -0.154264 -0.669409  0.246002  0.077041  0.901568
# 1 -0.630891  0.277553  0.046143 -0.809495 -0.274543
# 2 -0.008714 -1.661417 -1.141469  1.327418 -1.847111
# 3 -1.319035 -0.730936  0.538331 -0.184677  1.092977
# 4 -0.979346  0.016180  0.036878 -2.126047 -0.087363

# %%
# In fact we can also print the first 15 rows
df.head(15)
# Out:
#            A         B         C         D         E
# 0  -0.154264 -0.669409  0.246002  0.077041  0.901568
# 1  -0.630891  0.277553  0.046143 -0.809495 -0.274543
# 2  -0.008714 -1.661417 -1.141469  1.327418 -1.847111
# 3  -1.319035 -0.730936  0.538331 -0.184677  1.092977
# 4  -0.979346  0.016180  0.036878 -2.126047 -0.087363
# 5  -0.137140 -0.941323  0.053512 -0.241053  0.888967
# 6  -1.070942 -0.274415 -0.055378 -0.128113  0.006706
# 7   0.482874 -0.757396 -1.680472  1.811669  1.840326
# 8  -0.283825 -0.677324  1.112043 -0.831544  0.039019
# 9   0.065339  1.697909  0.208100 -0.918609  0.283299
# 10  0.359141 -1.431459  0.840759  1.786859 -1.240038
# 11 -0.284112 -0.148852 -0.128945  0.576144  1.260822
# 12 -0.379851 -1.602914 -1.222445 -1.708948  0.877243
# 13 -1.555801  1.470370  0.174842 -0.089535 -0.352099
# 14  1.627431 -1.121275  0.190605  0.145442 -0.000464

# %% [markdown]
# * ## <b><code>tail()</code></b>
#
# #### Prints the last $n$ rows of the dataframe. By default it prints the last 5 rows

# %%
df.tail()
# Out:
#            A         B         C         D         E
# 95  1.437503  1.803351 -0.057762 -1.873986 -0.277288
# 96  1.183045 -1.489355 -0.056778  0.230856  1.064244
# 97 -1.003252  1.364895  0.358077 -0.081595  1.076395
# 98 -1.365442 -2.000331  0.437474  0.449832 -2.209277
# 99 -0.578452 -1.168125 -0.788659  1.094292 -0.600941

# %%
df.tail(15)
# Out:
#            A         B         C         D         E
# 85  0.037038  0.998091 -0.277246  1.355217 -1.263694
# 86  1.876445  0.738226  0.430384 -1.440778 -0.733387
# 87  2.980635 -2.371829  0.040713  0.920943  0.456870
# 88 -0.543236 -1.121477 -0.233654  0.178457  1.228483
# 89  1.274312 -0.239326  0.920042 -0.184435  1.073189
# 90  0.086626  0.458626  0.085747 -1.514541  2.450421
# 91  1.381027 -0.604254  0.783215  1.056561  0.631398
# 92 -1.943786 -1.114794 -2.536731  0.683040  1.756644
# 93 -1.648961 -0.914184 -0.388355 -0.640110  0.981026
# 94  0.799149  2.102974  0.380825  1.985373 -0.603934
# 95  1.437503  1.803351 -0.057762 -1.873986 -0.277288
# 96  1.183045 -1.489355 -0.056778  0.230856  1.064244
# 97 -1.003252  1.364895  0.358077 -0.081595  1.076395
# 98 -1.365442 -2.000331  0.437474  0.449832 -2.209277
# 99 -0.578452 -1.168125 -0.788659  1.094292 -0.600941

# %% [markdown]
# * ## <b><code>columns</code></b>
#
# #### Prints the list of columns in a dataframe

# %%
list(df.columns)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
list(actor_df.columns)
# Out:
# ['Name', 'Age']

# %% [markdown]
# * ## <b><code>info()</code></b>
#
# #### Prints the basic information about our dataframe

# %%
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  62.0
# 2     Robert Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
actor_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      str
#  1   Age     3 non-null      float64
# dtypes: float64(1), str(1)
# memory usage: 196.0 bytes

# %% [markdown]
# * ## <b><code>rename()</code></b>
#
# #### Rename the columns of the dataframe

# %%
actor_df
# Out:
#                 Name   Age
# 0      Ryan Reynolds  48.0
# 1          Tom Hanks  62.0
# 2  Robert Downey Jr.  54.0
# 3        Chris Evans   NaN

# %%
actor_df.rename(columns = {'Name':'Actor Name','Age' :'Actor Age'}, inplace=True)

# %%
actor_df
# Out:
#              Actor Name  Actor Age
# 0         Ryan Reynolds       48.0
# 1  Benedict Cumberbatch       62.0
# 2     Robert Downey Jr.       54.0
# 3           Chris Evans        NaN

# %%
employee_df
# Out:
#   Employee Name  Income
# 0        Rajeev  200000
# 1         Sumit  140000
# 2        Aviral   90000

# %%
employee_df.rename(columns = {'Employee Name':'Name'}, inplace=True)

# %%
employee_df
# Out:
#      Name  Income
# 0  Rajeev  200000
# 1   Sumit  140000
# 2  Aviral   90000

# %%
employee_df = employee_df.rename({'Employee Name':'Name'},axis=1)

# %%
employee_df
# Out:
#      Name  Income
# 0  Rajeev  200000
# 1   Sumit  140000
# 2  Aviral   90000
# 3  Raghav  175000
