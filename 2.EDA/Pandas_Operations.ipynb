# %% [markdown]
# ## **Yesterday, we learnt a little about the very useful library Pandas widely used for Data Analysis. It is time to put the many utilities of this library in front of our eyes. We will be performing following manipulations and exploration of our data:**
#
# * ### Indexing and slicing operations
# * ### Manipulating columns
# * ### Exploring unique and missing values

# %%
# Import pandas package
import pandas as pd
import numpy as np

# %% [markdown]
# ## Let us read our data first

# %% [markdown]
# ### <u>Loading a CSV (Comma-Separated Values) file</u>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df=pd.read_csv(r"C:\Users\LakshmanAIMLHYD\Desktop\AI&ML(8-9)\2.EDA\imdb_pandas_practice_dataset.csv")

df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  \
# 0                        [{"name": "Comedy"}]
# 1     [{"name": "Comedy"}, {"name": "Drama"}]
# 2                         [{"name": "Drama"}]
# 3   [{"name": "Thriller"}, {"name": "Drama"}]
# 4  [{"name": "Action"}, {"name": "Thriller"}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  ...  \
# 0                                Time travel comedy.    6.575393  ...
# 1                  A princess prepares for marriage.    8.248895  ...
# 2       A young drummer faces a ruthless instructor.   64.299990  ...
# 3  A woman searches for her missing husband in Ko...    3.174936  ...
# 4        A former swimmer becomes involved in crime.    1.148070  ...
#
#   release_date runtime             spoken_languages    status  \
# 0      2/20/15    93.0        [{"name": "English"}]  Released
# 1       8/6/04   113.0        [{"name": "English"}]  Released
# 2     10/10/14   105.0        [{"name": "English"}]  Released
# 3       3/9/12   122.0  [{"name": "English|Hindi"}]  Released
# 4       2/5/09   118.0         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                                              NaN
# 4                                              NaN
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy               NaN
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (30, 23)

# %%
df.tail()
# Out:
#     id        belongs_to_collection     budget  \
# 25  26                          RRR  550000000
# 26  27   Bahubali 2: The Conclusion  250000000
# 27  28                        Joker   55000000
# 28  29                   La La Land   30000000
# 29  30  Dilwale Dulhania Le Jayenge   40000000
#
#                                                genres homepage    imdb_id  \
# 25            [{"name": "Action"}, {"name": "Drama"}]      NaN  tt8178634
# 26            [{"name": "Action"}, {"name": "Drama"}]      NaN  tt4849438
# 27             [{"name": "Crime"}, {"name": "Drama"}]      NaN  tt7286456
# 28  [{"name": "Comedy"}, {"name": "Drama"}, {"name...      NaN  tt3783958
# 29           [{"name": "Drama"}, {"name": "Romance"}]      NaN  tt0112870
#
#    original_language               original_title  \
# 25                te                          RRR
# 26                te  Baahubali 2: The Conclusion
# 27                en                        Joker
# 28                en                   La La Land
# 29                hi  Dilwale Dulhania Le Jayenge
#
#                                              overview  popularity  ...  \
# 25   Two revolutionaries form an unlikely friendship.        60.3  ...
# 26               A kingdom seeks answers and revenge.        52.9  ...
# 27             A failed comedian descends into chaos.        70.9  ...
# 28  A musician and actress pursue dreams in Los An...        35.8  ...
# 29     A young couple challenges family expectations.        20.6  ...
#
#    release_date runtime       spoken_languages    status  \
# 25      3/25/22   187.0   [{"name": "Telugu"}]  Released
# 26      4/28/17   168.0   [{"name": "Telugu"}]  Released
# 27      10/4/19   122.0  [{"name": "English"}]  Released
# 28     12/25/16   128.0  [{"name": "English"}]  Released
# 29     10/20/95   181.0    [{"name": "Hindi"}]  Released
#
#                              tagline                        title  \
# 25               Rise. Roar. Revolt.                          RRR
# 26  Why did Kattappa kill Baahubali?  Baahubali 2: The Conclusion
# 27              Put on a happy face.                        Joker
# 28    Here's to the fools who dream.                   La La Land
# 29             Come... Fall in love.  Dilwale Dulhania Le Jayenge
#
#                  Keywords                              cast  \
# 25  friendship|revolution  [{"name": "N. T. Rama Rao Jr."}]
# 26            kingdom|war             [{"name": "Prabhas"}]
# 27            joker|crime     [{"name": "Joaquin Phoenix"}]
# 28      music|los angeles        [{"name": "Ryan Gosling"}]
# 29         romance|family      [{"name": "Shah Rukh Khan"}]
#
#                                                 crew     revenue
# 25  [{"name": "S. S. Rajamouli", "job": "Director"}]  1200000000
# 26  [{"name": "S. S. Rajamouli", "job": "Director"}]  1810000000
# 27    [{"name": "Todd Phillips", "job": "Director"}]  1074251311
# 28  [{"name": "Damien Chazelle", "job": "Director"}]   472000000
# 29    [{"name": "Aditya Chopra", "job": "Director"}]   120000000
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (30, 23)

# %%
df.poster_path[:10]
# Out:
# 0     /poster1.jpg
# 1     /poster2.jpg
# 2     /poster3.jpg
# 3     /poster4.jpg
# 4     /poster5.jpg
# 5     /poster6.jpg
# 6     /poster7.jpg
# 7     /poster8.jpg
# 8     /poster9.jpg
# 9    /poster10.jpg
# Name: poster_path, dtype: str

# %%
df.production_companies[:10]
# Out:
# 0      [{"name": "Paramount Pictures"}]
# 1    [{"name": "Walt Disney Pictures"}]
# 2              [{"name": "Bold Films"}]
# 3                                   NaN
# 4                                   NaN
# 5            [{"name": "Warner Bros."}]
# 6            [{"name": "Warner Bros."}]
# 7      [{"name": "Vinod Chopra Films"}]
# 8            [{"name": "Barunson E&A"}]
# 9          [{"name": "DreamWorks SKG"}]
# Name: production_companies, dtype: str

# %%
df.production_countries[:9]
# Out:
# 0    [{"iso_3166_1": "US"}]
# 1    [{"iso_3166_1": "US"}]
# 2    [{"iso_3166_1": "US"}]
# 3    [{"iso_3166_1": "IN"}]
# 4    [{"iso_3166_1": "KR"}]
# 5    [{"iso_3166_1": "US"}]
# 6    [{"iso_3166_1": "US"}]
# 7    [{"iso_3166_1": "IN"}]
# 8    [{"iso_3166_1": "KR"}]
# Name: production_countries, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     30 non-null     int64
#  1   belongs_to_collection  30 non-null     str
#  2   budget                 30 non-null     int64
#  3   genres                 29 non-null     str
#  4   homepage               9 non-null      str
#  5   imdb_id                30 non-null     str
#  6   original_language      30 non-null     str
#  7   original_title         30 non-null     str
#  8   overview               30 non-null     str
#  9   popularity             30 non-null     float64
#  10  poster_path            29 non-null     str
#  11  production_companies   27 non-null     str
#  12  production_countries   30 non-null     str
#  13  release_date           30 non-null     str
#  14  runtime                29 non-null     float64
#  15  spoken_languages       30 non-null     str
#  16  status                 30 non-null     str
#  17  tagline                25 non-null     str
#  18  title                  30 non-null     str
#  19  Keywords               29 non-null     str
#  20  cast                   30 non-null     str
#  21  crew                   30 non-null     str
#  22  revenue                30 non-null     int64
# dtypes: float64(2), int64(3), str(18)
# memory usage: 5.5 KB

# %% [markdown]
# - # data insights
#
# - genres has 1 null value
#
# - homepage has 21 null values
#
# - imdb_id has datatype wrong
#
# - poster_path has one missing value
#
# - release_date has wrong type of data
#
# - runtime has one null value
#
# - tagline has 5 null values
#
# - Keywords has one null value

# %% [markdown]
# # <u>**<code>describe()</code>**</u>
#
# ## This method gives the overall descriptive summary of the dataframe. This works only for numerical columns

# %%
df.describe().T        # numberical data
# Out:
#             count          mean           std      min           25%  \
# id           30.0  1.550000e+01  8.803408e+00  1.00000  8.250000e+00
# budget       30.0  1.009633e+08  1.492895e+08  0.00000  1.205000e+07
# popularity   30.0  3.904264e+01  3.146144e+01  1.14807  1.100908e+01
# runtime      29.0  1.326207e+02  4.006371e+01  0.00000  1.060000e+02
# revenue      30.0  5.554160e+08  7.579332e+08  0.00000  2.325000e+07
#
#                      50%           75%           max
# id          1.550000e+01  2.275000e+01  3.000000e+01
# budget      4.000000e+07  1.400000e+08  5.500000e+08
# popularity  3.035000e+01  6.925000e+01  9.530000e+01
# runtime     1.280000e+02  1.680000e+02  1.940000e+02
# revenue     2.347086e+08  8.046823e+08  2.797501e+09

# %% [markdown]
# - i observe budget n revenue feels outliers , i have to check with boxplot

# %%
df.original_language.value_counts()
# Out:
# original_language
# en    18
# hi     5
# ko     2
# te     2
# sv     1
# ja     1
# kn     1
# Name: count, dtype: int64

# %%
df.describe(include="object" or "str" or "categorical").T
# Out:
# C:\Users\LakshmanAIMLHYD\AppData\Local\Temp\ipykernel_21544\2979308790.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object" or "str" or "categorical").T
#                       count unique  \
# belongs_to_collection    30     30
# genres                   29     20
# homepage                  9      9
# imdb_id                  30     30
# original_language        30      7
# original_title           30     30
# overview                 30     30
# poster_path              29     29
# production_companies     27     21
# production_countries     30      5
# release_date             30     30
# spoken_languages         30      8
# status                   30      2
# tagline                  25     25
# title                    30     30
# Keywords                 29     29
# cast                     30     27
# crew                     30     26
#
#                                                                      top freq
# belongs_to_collection                             Hot Tub Time Machine 2    1
# genres                           [{"name": "Comedy"}, {"name": "Drama"}]    4
# homepage                               http://sonyclassics.com/whiplash/    1
# imdb_id                                                        tt2637294    1
# original_language                                                     en   18
# original_title                                    Hot Tub Time Machine 2    1
# overview                                             Time travel comedy.    1
# poster_path                                                 /poster1.jpg    1
# production_companies                    [{"name": "Paramount Pictures"}]    4
# production_countries                              [{"iso_3166_1": "US"}]   18
# release_date                                                     2/20/15    1
# spoken_languages                                   [{"name": "English"}]   18
# status                                                          Released   29
# tagline                                       The Laws of Space and Time    1
# title                                             Hot Tub Time Machine 2    1
# Keywords                                                     time travel    1
# cast                                            [{"name": "Aamir Khan"}]    3
# crew                   [{"name": "Christopher Nolan", "job": "Directo...    3

# %% [markdown]
# - finding columns

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='str')

# %% [markdown]
# - drop duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# df.drop_duplicates()

# %% [markdown]
# # Null values

# %%
df.isnull()
# Out:
#        id  belongs_to_collection  budget  genres  homepage  imdb_id  \
# 0   False                  False   False   False      True    False
# 1   False                  False   False   False      True    False
# 2   False                  False   False   False     False    False
# 3   False                  False   False   False     False    False
# 4   False                  False   False   False      True    False
# 5   False                  False   False   False     False    False
# 6   False                  False   False   False      True    False
# 7   False                  False   False   False     False    False
# 8   False                  False   False   False      True    False
# 9   False                  False   False   False     False    False
# 10  False                  False   False   False      True    False
# 11  False                  False   False   False      True    False
# 12  False                  False   False   False      True    False
# 13  False                  False   False   False      True    False
# 14  False                  False   False   False     False    False
# 15  False                  False   False   False     False    False
# 16  False                  False   False   False      True    False
# 17  False                  False   False   False      True    False
# 18  False                  False   False   False      True    False
# 19  False                  False   False   False      True    False
# 20  False                  False   False   False     False    False
# 21  False                  False   False   False      True    False
# 22  False                  False   False   False      True    False
# 23  False                  False   False    True      True    False
# 24  False                  False   False   False     False    False
# 25  False                  False   False   False      True    False
# 26  False                  False   False   False      True    False
# 27  False                  False   False   False      True    False
# 28  False                  False   False   False      True    False
# 29  False                  False   False   False      True    False
#
#     original_language  original_title  overview  popularity  ...  \
# 0               False           False     False       False  ...
# 1               False           False     False       False  ...
# 2               False           False     False       False  ...
# 3               False           False     False       False  ...
# 4               False           False     False       False  ...
# 5               False           False     False       False  ...
# 6               False           False     False       False  ...
# 7               False           False     False       False  ...
# 8               False           False     False       False  ...
# 9               False           False     False       False  ...
# 10              False           False     False       False  ...
# 11              False           False     False       False  ...
# 12              False           False     False       False  ...
# 13              False           False     False       False  ...
# 14              False           False     False       False  ...
# 15              False           False     False       False  ...
# 16              False           False     False       False  ...
# 17              False           False     False       False  ...
# 18              False           False     False       False  ...
# 19              False           False     False       False  ...
# 20              False           False     False       False  ...
# 21              False           False     False       False  ...
# 22              False           False     False       False  ...
# 23              False           False     False       False  ...
# 24              False           False     False       False  ...
# 25              False           False     False       False  ...
# 26              False           False     False       False  ...
# 27              False           False     False       False  ...
# 28              False           False     False       False  ...
# 29              False           False     False       False  ...
#
#     release_date  runtime  spoken_languages  status  tagline  title  Keywords  \
# 0          False    False             False   False    False  False     False
# 1          False    False             False   False    False  False     False
# 2          False    False             False   False    False  False     False
# 3          False    False             False   False     True  False     False
# 4          False    False             False   False     True  False      True
# 5          False    False             False   False    False  False     False
# 6          False    False             False   False    False  False     False
# 7          False    False             False   False    False  False     False
# 8          False    False             False   False    False  False     False
# 9          False    False             False   False    False  False     False
# 10         False    False             False   False    False  False     False
# 11         False    False             False   False    False  False     False
# 12         False    False             False   False     True  False     False
# 13         False    False             False   False    False  False     False
# 14         False    False             False   False    False  False     False
# 15         False    False             False   False    False  False     False
# 16         False    False             False   False    False  False     False
# 17         False    False             False   False    False  False     False
# 18         False    False             False   False    False  False     False
# 19         False    False             False   False    False  False     False
# 20         False    False             False   False    False  False     False
# 21         False    False             False   False    False  False     False
# 22         False    False             False   False     True  False     False
# 23         False     True             False   False     True  False     False
# 24         False    False             False   False    False  False     False
# 25         False    False             False   False    False  False     False
# 26         False    False             False   False    False  False     False
# 27         False    False             False   False    False  False     False
# 28         False    False             False   False    False  False     False
# 29         False    False             False   False    False  False     False
#
#      cast   crew  revenue
# 0   False  False    False
# 1   False  False    False
# 2   False  False    False
# 3   False  False    False
# 4   False  False    False
# 5   False  False    False
# 6   False  False    False
# 7   False  False    False
# 8   False  False    False
# 9   False  False    False
# 10  False  False    False
# 11  False  False    False
# 12  False  False    False
# 13  False  False    False
# 14  False  False    False
# 15  False  False    False
# 16  False  False    False
# 17  False  False    False
# 18  False  False    False
# 19  False  False    False
# 20  False  False    False
# 21  False  False    False
# 22  False  False    False
# 23  False  False    False
# 24  False  False    False
# 25  False  False    False
# 26  False  False    False
# 27  False  False    False
# 28  False  False    False
# 29  False  False    False
#
# [30 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# id                        0
# belongs_to_collection     0
# budget                    0
# genres                    1
# homepage                 21
# imdb_id                   0
# original_language         0
# original_title            0
# overview                  0
# popularity                0
# poster_path               1
# production_companies      3
# production_countries      0
# release_date              0
# runtime                   1
# spoken_languages          0
# status                    0
# tagline                   5
# title                     0
# Keywords                  1
# cast                      0
# crew                      0
# revenue                   0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# id                        0.000000
# belongs_to_collection     0.000000
# budget                    0.000000
# genres                    3.333333
# homepage                 70.000000
# imdb_id                   0.000000
# original_language         0.000000
# original_title            0.000000
# overview                  0.000000
# popularity                0.000000
# poster_path               3.333333
# production_companies     10.000000
# production_countries      0.000000
# release_date              0.000000
# runtime                   3.333333
# spoken_languages          0.000000
# status                    0.000000
# tagline                  16.666667
# title                     0.000000
# Keywords                  3.333333
# cast                      0.000000
# crew                      0.000000
# revenue                   0.000000
# dtype: float64

# %%
df.drop(columns=["homepage"],inplace=True)  # if morethan 25% we have to remove

# %%
df.shape
# Out:
# (30, 22)

# %%
df.head(1)
# Out:
#    id   belongs_to_collection    budget                genres    imdb_id  \
# 0   1  Hot Tub Time Machine 2  14000000  [{"name": "Comedy"}]  tt2637294
#
#   original_language          original_title             overview  popularity  \
# 0                en  Hot Tub Time Machine 2  Time travel comedy.    6.575393
#
#     poster_path  ... release_date runtime       spoken_languages    status  \
# 0  /poster1.jpg  ...      2/20/15    93.0  [{"name": "English"}]  Released
#
#                       tagline                   title     Keywords  \
# 0  The Laws of Space and Time  Hot Tub Time Machine 2  time travel
#
#                         cast                                         crew  \
# 0  [{"name": "Rob Corddry"}]  [{"name": "Steve Pink", "job": "Director"}]
#
#     revenue
# 0  12314651
#
# [1 rows x 22 columns]

# %% [markdown]
# - filling missing values

# %%
df.genres=df.genres.fillna(df.genres.mode()[0])

# %%
df['poster_path']=df['poster_path'].fillna(df["poster_path"].mode()[0])

# %%
df.production_companies=df.production_companies.fillna(df.production_companies.mode()[0])

# %%
df.runtime=df.runtime.fillna(df.runtime.mean())

# %%
df.tagline=df.tagline.fillna(df.tagline.mode()[0])

# %%
df.Keywords=df.Keywords.fillna(df.Keywords.mode()[0])

# %%
df.isnull().sum()
# Out:
# id                       0
# belongs_to_collection    0
# budget                   0
# genres                   0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# Keywords                 0
# cast                     0
# crew                     0
# revenue                  0
# dtype: int64

# %% [markdown]
# - fixing datatype issue

# %%
df.dtypes
# Out:
# id                         int64
# belongs_to_collection        str
# budget                     int64
# genres                       str
# imdb_id                      str
# original_language            str
# original_title               str
# overview                     str
# popularity               float64
# poster_path                  str
# production_companies         str
# production_countries         str
# release_date                 str
# runtime                  float64
# spoken_languages             str
# status                       str
# tagline                      str
# title                        str
# Keywords                     str
# cast                         str
# crew                         str
# revenue                    int64
# dtype: object

# %%
df.imdb_id.value_counts()
# Out:
# imdb_id
# tt2637294     1
# tt0368933     1
# tt2582802     1
# tt1821480     1
# tt1380152     1
# tt1375666     1
# tt0468569     1
# tt1187043     1
# tt6751668     1
# tt0362227     1
# tt0105327     1
# tt0109403     1
# tt2364975     1
# tt0116908     1
# tt0343135     1
# tt1600195     1
# tt0816692     1
# tt5074352     1
# tt4154796     1
# tt0120338     1
# tt0245429     1
# tt0068646     1
# tt9000001     1
# tt9000002     1
# tt15327088    1
# tt8178634     1
# tt4849438     1
# tt7286456     1
# tt3783958     1
# tt0112870     1
# Name: count, dtype: int64

# %%
df["imdb_id"] = df["imdb_id"].str.replace("tt", "", regex=False)

# %%
df.imdb_id.value_counts()
# Out:
# imdb_id
# 2637294     1
# 0368933     1
# 2582802     1
# 1821480     1
# 1380152     1
# 1375666     1
# 0468569     1
# 1187043     1
# 6751668     1
# 0362227     1
# 0105327     1
# 0109403     1
# 2364975     1
# 0116908     1
# 0343135     1
# 1600195     1
# 0816692     1
# 5074352     1
# 4154796     1
# 0120338     1
# 0245429     1
# 0068646     1
# 9000001     1
# 9000002     1
# 15327088    1
# 8178634     1
# 4849438     1
# 7286456     1
# 3783958     1
# 0112870     1
# Name: count, dtype: int64

# %%
df.imdb_id=df.imdb_id.astype("int64")

# %%
df.dtypes
# Out:
# id                         int64
# belongs_to_collection        str
# budget                     int64
# genres                       str
# imdb_id                    int64
# original_language            str
# original_title               str
# overview                     str
# popularity               float64
# poster_path                  str
# production_companies         str
# production_countries         str
# release_date                 str
# runtime                  float64
# spoken_languages             str
# status                       str
# tagline                      str
# title                        str
# Keywords                     str
# cast                         str
# crew                         str
# revenue                    int64
# dtype: object

# %%
df.release_date[0]
# Out:
# '2/20/15'

# %%
df.release_date=pd.to_datetime(df.release_date,format="%m-%d-%y",errors="coerce")

# %%
df.dtypes
# Out:
# id                               int64
# belongs_to_collection              str
# budget                           int64
# genres                             str
# imdb_id                          int64
# original_language                  str
# original_title                     str
# overview                           str
# popularity                     float64
# poster_path                        str
# production_companies               str
# production_countries               str
# release_date             datetime64[s]
# runtime                        float64
# spoken_languages                   str
# status                             str
# tagline                            str
# title                              str
# Keywords                           str
# cast                               str
# crew                               str
# revenue                          int64
# dtype: object

# %%
df.head(5)
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#     poster_path  ... release_date runtime             spoken_languages  \
# 0  /poster1.jpg  ...          NaT    93.0        [{"name": "English"}]
# 1  /poster2.jpg  ...          NaT   113.0        [{"name": "English"}]
# 2  /poster3.jpg  ...          NaT   105.0        [{"name": "English"}]
# 3  /poster4.jpg  ...          NaT   122.0  [{"name": "English|Hindi"}]
# 4  /poster5.jpg  ...          NaT   118.0         [{"name": "Korean"}]
#
#      status                                          tagline  \
# 0  Released                       The Laws of Space and Time
# 1  Released        It can take a lifetime to find true love.
# 2  Released  The road to greatness can take you to the edge.
# 3  Released                      Act like you own the place.
# 4  Released                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970
#
# [5 rows x 22 columns]

# %% [markdown]
# # <u>**Indexing and Slicing**</u>

# %%
df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#     poster_path  ... release_date runtime             spoken_languages  \
# 0  /poster1.jpg  ...          NaT    93.0        [{"name": "English"}]
# 1  /poster2.jpg  ...          NaT   113.0        [{"name": "English"}]
# 2  /poster3.jpg  ...          NaT   105.0        [{"name": "English"}]
# 3  /poster4.jpg  ...          NaT   122.0  [{"name": "English|Hindi"}]
# 4  /poster5.jpg  ...          NaT   118.0         [{"name": "Korean"}]
#
#      status                                          tagline  \
# 0  Released                       The Laws of Space and Time
# 1  Released        It can take a lifetime to find true love.
# 2  Released  The road to greatness can take you to the edge.
# 3  Released                      Act like you own the place.
# 4  Released                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970
#
# [5 rows x 22 columns]

# %% [markdown]
# ## **<code>iloc</code>** gets rows (or columns) at particular positions in the index (so it only takes integers).

# %%
df.iloc[1:10 , 1:4]
# Out:
#                       belongs_to_collection     budget  \
# 1  The Princess Diaries 2: Royal Engagement   40000000
# 2                                  Whiplash    3300000
# 3                                   Kahaani    1200000
# 4                                Marine Boy          0
# 5                                 Inception  160000000
# 6                           The Dark Knight  185000000
# 7                                  3 Idiots  550000000
# 8                                  Parasite   11400000
# 9                              The Terminal   60000000
#
#                                               genres
# 1            [{"name": "Comedy"}, {"name": "Drama"}]
# 2                                [{"name": "Drama"}]
# 3          [{"name": "Thriller"}, {"name": "Drama"}]
# 4         [{"name": "Action"}, {"name": "Thriller"}]
# 5           [{"name": "Action"}, {"name": "Sci-Fi"}]
# 6  [{"name": "Action"}, {"name": "Crime"}, {"name...
# 7            [{"name": "Comedy"}, {"name": "Drama"}]
# 8          [{"name": "Drama"}, {"name": "Thriller"}]
# 9            [{"name": "Comedy"}, {"name": "Drama"}]

# %%
df.iloc[5:19 , 2:7]
# Out:
#        budget                                             genres  imdb_id  \
# 5   160000000           [{"name": "Action"}, {"name": "Sci-Fi"}]  1375666
# 6   185000000  [{"name": "Action"}, {"name": "Crime"}, {"name...   468569
# 7   550000000            [{"name": "Comedy"}, {"name": "Drama"}]  1187043
# 8    11400000          [{"name": "Drama"}, {"name": "Thriller"}]  6751668
# 9    60000000            [{"name": "Comedy"}, {"name": "Drama"}]   362227
# 10          0                                [{"name": "Drama"}]   105327
# 11          0          [{"name": "Comedy"}, {"name": "Romance"}]   109403
# 12          0             [{"name": "Drama"}, {"name": "Music"}]  2364975
# 13   65000000            [{"name": "Crime"}, {"name": "Action"}]   116908
# 14   42000000          [{"name": "Comedy"}, {"name": "Romance"}]   343135
# 15   35000000         [{"name": "Thriller"}, {"name": "Action"}]  1600195
# 16  165000000  [{"name": "Adventure"}, {"name": "Drama"}, {"n...   816692
# 17   70000000             [{"name": "Drama"}, {"name": "Sport"}]  5074352
# 18  356000000  [{"name": "Action"}, {"name": "Adventure"}, {"...  4154796
#
#    original_language           original_title
# 5                 en                Inception
# 6                 en          The Dark Knight
# 7                 hi                 3 Idiots
# 8                 ko                 Parasite
# 9                 en             The Terminal
# 10                en              School Ties
# 11                en                  Chasers
# 12                sv         We Are the Best!
# 13                en  The Long Kiss Goodnight
# 14                en         Along Came Polly
# 15                en                Abduction
# 16                en             Interstellar
# 17                hi                   Dangal
# 18                en        Avengers: Endgame

# %% [markdown]
# ## **<code>loc</code>** gets rows (or columns) with particular labels from the index.

# %%
df.shape
# Out:
# (30, 22)

# %%
# Now let us subset our dataframe in which we want to have first 8 rows identified with their rows labels and some named columns
df.loc[5:22,['budget','genres','runtime',"original_language"]]
# Out:
#        budget                                             genres  runtime  \
# 5   160000000           [{"name": "Action"}, {"name": "Sci-Fi"}]    148.0
# 6   185000000  [{"name": "Action"}, {"name": "Crime"}, {"name...    152.0
# 7   550000000            [{"name": "Comedy"}, {"name": "Drama"}]    170.0
# 8    11400000          [{"name": "Drama"}, {"name": "Thriller"}]    132.0
# 9    60000000            [{"name": "Comedy"}, {"name": "Drama"}]    128.0
# 10          0                                [{"name": "Drama"}]    106.0
# 11          0          [{"name": "Comedy"}, {"name": "Romance"}]    102.0
# 12          0             [{"name": "Drama"}, {"name": "Music"}]    102.0
# 13   65000000            [{"name": "Crime"}, {"name": "Action"}]    120.0
# 14   42000000          [{"name": "Comedy"}, {"name": "Romance"}]     90.0
# 15   35000000         [{"name": "Thriller"}, {"name": "Action"}]    106.0
# 16  165000000  [{"name": "Adventure"}, {"name": "Drama"}, {"n...    169.0
# 17   70000000             [{"name": "Drama"}, {"name": "Sport"}]    161.0
# 18  356000000  [{"name": "Action"}, {"name": "Adventure"}, {"...    181.0
# 19  200000000           [{"name": "Drama"}, {"name": "Romance"}]    194.0
# 20   19000000       [{"name": "Animation"}, {"name": "Fantasy"}]    125.0
# 21    6000000             [{"name": "Crime"}, {"name": "Drama"}]    175.0
# 22   80000000            [{"name": "Comedy"}, {"name": "Drama"}]      0.0
#
#    original_language
# 5                 en
# 6                 en
# 7                 hi
# 8                 ko
# 9                 en
# 10                en
# 11                en
# 12                sv
# 13                en
# 14                en
# 15                en
# 16                en
# 17                hi
# 18                en
# 19                en
# 20                ja
# 21                en
# 22                hi

# %%
df.loc[      :       ,   ['budget','genres','runtime']]
# Out:
#        budget                                             genres    runtime
# 0    14000000                               [{"name": "Comedy"}]   93.00000
# 1    40000000            [{"name": "Comedy"}, {"name": "Drama"}]  113.00000
# 2     3300000                                [{"name": "Drama"}]  105.00000
# 3     1200000          [{"name": "Thriller"}, {"name": "Drama"}]  122.00000
# 4           0         [{"name": "Action"}, {"name": "Thriller"}]  118.00000
# 5   160000000           [{"name": "Action"}, {"name": "Sci-Fi"}]  148.00000
# 6   185000000  [{"name": "Action"}, {"name": "Crime"}, {"name...  152.00000
# 7   550000000            [{"name": "Comedy"}, {"name": "Drama"}]  170.00000
# 8    11400000          [{"name": "Drama"}, {"name": "Thriller"}]  132.00000
# 9    60000000            [{"name": "Comedy"}, {"name": "Drama"}]  128.00000
# 10          0                                [{"name": "Drama"}]  106.00000
# 11          0          [{"name": "Comedy"}, {"name": "Romance"}]  102.00000
# 12          0             [{"name": "Drama"}, {"name": "Music"}]  102.00000
# 13   65000000            [{"name": "Crime"}, {"name": "Action"}]  120.00000
# 14   42000000          [{"name": "Comedy"}, {"name": "Romance"}]   90.00000
# 15   35000000         [{"name": "Thriller"}, {"name": "Action"}]  106.00000
# 16  165000000  [{"name": "Adventure"}, {"name": "Drama"}, {"n...  169.00000
# 17   70000000             [{"name": "Drama"}, {"name": "Sport"}]  161.00000
# 18  356000000  [{"name": "Action"}, {"name": "Adventure"}, {"...  181.00000
# 19  200000000           [{"name": "Drama"}, {"name": "Romance"}]  194.00000
# 20   19000000       [{"name": "Animation"}, {"name": "Fantasy"}]  125.00000
# 21    6000000             [{"name": "Crime"}, {"name": "Drama"}]  175.00000
# 22   80000000            [{"name": "Comedy"}, {"name": "Drama"}]    0.00000
# 23   25000000            [{"name": "Comedy"}, {"name": "Drama"}]  132.62069
# 24   16000000            [{"name": "Action"}, {"name": "Drama"}]  148.00000
# 25  550000000            [{"name": "Action"}, {"name": "Drama"}]  187.00000
# 26  250000000            [{"name": "Action"}, {"name": "Drama"}]  168.00000
# 27   55000000             [{"name": "Crime"}, {"name": "Drama"}]  122.00000
# 28   30000000  [{"name": "Comedy"}, {"name": "Drama"}, {"name...  128.00000
# 29   40000000           [{"name": "Drama"}, {"name": "Romance"}]  181.00000

# %%
df[0:10]
# Out:
#    id                     belongs_to_collection     budget  \
# 0   1                    Hot Tub Time Machine 2   14000000
# 1   2  The Princess Diaries 2: Royal Engagement   40000000
# 2   3                                  Whiplash    3300000
# 3   4                                   Kahaani    1200000
# 4   5                                Marine Boy          0
# 5   6                                 Inception  160000000
# 6   7                           The Dark Knight  185000000
# 7   8                                  3 Idiots  550000000
# 8   9                                  Parasite   11400000
# 9  10                              The Terminal   60000000
#
#                                               genres  imdb_id  \
# 0                               [{"name": "Comedy"}]  2637294
# 1            [{"name": "Comedy"}, {"name": "Drama"}]   368933
# 2                                [{"name": "Drama"}]  2582802
# 3          [{"name": "Thriller"}, {"name": "Drama"}]  1821480
# 4         [{"name": "Action"}, {"name": "Thriller"}]  1380152
# 5           [{"name": "Action"}, {"name": "Sci-Fi"}]  1375666
# 6  [{"name": "Action"}, {"name": "Crime"}, {"name...   468569
# 7            [{"name": "Comedy"}, {"name": "Drama"}]  1187043
# 8          [{"name": "Drama"}, {"name": "Thriller"}]  6751668
# 9            [{"name": "Comedy"}, {"name": "Drama"}]   362227
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                Marine Boy
# 5                en                                 Inception
# 6                en                           The Dark Knight
# 7                hi                                  3 Idiots
# 8                ko                                  Parasite
# 9                en                              The Terminal
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
# 5            A thief enters dreams to steal secrets.   82.500000
# 6                            Batman faces the Joker.   90.100000
# 7           Three friends navigate college and life.   25.300000
# 8  Two families become entangled in a strange sit...   55.700000
# 9              A man becomes stranded in an airport.   14.092373
#
#      poster_path  ... release_date runtime             spoken_languages  \
# 0   /poster1.jpg  ...          NaT    93.0        [{"name": "English"}]
# 1   /poster2.jpg  ...          NaT   113.0        [{"name": "English"}]
# 2   /poster3.jpg  ...          NaT   105.0        [{"name": "English"}]
# 3   /poster4.jpg  ...          NaT   122.0  [{"name": "English|Hindi"}]
# 4   /poster5.jpg  ...          NaT   118.0         [{"name": "Korean"}]
# 5   /poster6.jpg  ...          NaT   148.0        [{"name": "English"}]
# 6   /poster7.jpg  ...          NaT   152.0        [{"name": "English"}]
# 7   /poster8.jpg  ...          NaT   170.0          [{"name": "Hindi"}]
# 8   /poster9.jpg  ...          NaT   132.0         [{"name": "Korean"}]
# 9  /poster10.jpg  ...          NaT   128.0        [{"name": "English"}]
#
#      status                                          tagline  \
# 0  Released                       The Laws of Space and Time
# 1  Released        It can take a lifetime to find true love.
# 2  Released  The road to greatness can take you to the edge.
# 3  Released                      Act like you own the place.
# 4  Released                      Act like you own the place.
# 5  Released             Your mind is the scene of the crime.
# 6  Released                                  Why so serious?
# 7  Released                                     All is well.
# 8  Released                      Act like you own the place.
# 9  Released                                 Life is waiting.
#
#                                       title            Keywords  \
# 0                    Hot Tub Time Machine 2         time travel
# 1  The Princess Diaries 2: Royal Engagement    princess|royalty
# 2                                  Whiplash          jazz|music
# 3                                   Kahaani     mystery|kolkata
# 4                                Marine Boy      CIA|conspiracy
# 5                                 Inception         dream|heist
# 6                           The Dark Knight        joker|batman
# 7                                  3 Idiots  college|friendship
# 8                                  Parasite        family|class
# 9                              The Terminal    airport|new york
#
#                               cast  \
# 0        [{"name": "Rob Corddry"}]
# 1      [{"name": "Anne Hathaway"}]
# 2       [{"name": "Miles Teller"}]
# 3        [{"name": "Vidya Balan"}]
# 4       [{"name": "Kim Kang-woo"}]
# 5  [{"name": "Leonardo DiCaprio"}]
# 6     [{"name": "Christian Bale"}]
# 7         [{"name": "Aamir Khan"}]
# 8       [{"name": "Song Kang-ho"}]
# 9          [{"name": "Tom Hanks"}]
#
#                                                 crew     revenue
# 0        [{"name": "Steve Pink", "job": "Director"}]    12314651
# 1    [{"name": "Garry Marshall", "job": "Director"}]    95149435
# 2   [{"name": "Damien Chazelle", "job": "Director"}]    13092000
# 3       [{"name": "Sujoy Ghosh", "job": "Director"}]    16000000
# 4    [{"name": "Yoon Jong-chan", "job": "Director"}]     3923970
# 5  [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6  [{"name": "Christopher Nolan", "job": "Directo...  1004558444
# 7   [{"name": "Rajkumar Hirani", "job": "Director"}]  2000000000
# 8      [{"name": "Bong Joon Ho", "job": "Director"}]   258000000
# 9  [{"name": "Steven Spielberg", "job": "Director"}]   219417255
#
# [10 rows x 22 columns]

# %%
df[ ['original_language','cast'] ] [:16]
# Out:
#    original_language                             cast
# 0                 en        [{"name": "Rob Corddry"}]
# 1                 en      [{"name": "Anne Hathaway"}]
# 2                 en       [{"name": "Miles Teller"}]
# 3                 hi        [{"name": "Vidya Balan"}]
# 4                 ko       [{"name": "Kim Kang-woo"}]
# 5                 en  [{"name": "Leonardo DiCaprio"}]
# 6                 en     [{"name": "Christian Bale"}]
# 7                 hi         [{"name": "Aamir Khan"}]
# 8                 ko       [{"name": "Song Kang-ho"}]
# 9                 en          [{"name": "Tom Hanks"}]
# 10                en     [{"name": "Brendan Fraser"}]
# 11                en       [{"name": "Tom Berenger"}]
# 12                sv    [{"name": "Mira Barkhammar"}]
# 13                en        [{"name": "Geena Davis"}]
# 14                en        [{"name": "Ben Stiller"}]
# 15                en     [{"name": "Taylor Lautner"}]

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %% [markdown]
# ## <b>In fact we can also perform boolean indexing on our dataframe</b>

# %%
df['original_language'] == 'en'
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29    False
# Name: original_language, dtype: bool

# %%
df[df['original_language'] == 'en']
# Out:
#    id                     belongs_to_collection     budget  \
# 0   1                    Hot Tub Time Machine 2   14000000
# 1   2  The Princess Diaries 2: Royal Engagement   40000000
# 2   3                                  Whiplash    3300000
# 5   6                                 Inception  160000000
# 6   7                           The Dark Knight  185000000
#
#                                               genres  imdb_id  \
# 0                               [{"name": "Comedy"}]  2637294
# 1            [{"name": "Comedy"}, {"name": "Drama"}]   368933
# 2                                [{"name": "Drama"}]  2582802
# 5           [{"name": "Action"}, {"name": "Sci-Fi"}]  1375666
# 6  [{"name": "Action"}, {"name": "Crime"}, {"name...   468569
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 5                en                                 Inception
# 6                en                           The Dark Knight
#
#                                        overview  popularity   poster_path  \
# 0                           Time travel comedy.    6.575393  /poster1.jpg
# 1             A princess prepares for marriage.    8.248895  /poster2.jpg
# 2  A young drummer faces a ruthless instructor.   64.299990  /poster3.jpg
# 5       A thief enters dreams to steal secrets.   82.500000  /poster6.jpg
# 6                       Batman faces the Joker.   90.100000  /poster7.jpg
#
#    ... release_date runtime       spoken_languages    status  \
# 0  ...          NaT    93.0  [{"name": "English"}]  Released
# 1  ...          NaT   113.0  [{"name": "English"}]  Released
# 2  ...          NaT   105.0  [{"name": "English"}]  Released
# 5  ...          NaT   148.0  [{"name": "English"}]  Released
# 6  ...          NaT   152.0  [{"name": "English"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 5             Your mind is the scene of the crime.
# 6                                  Why so serious?
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 5                                 Inception       dream|heist
# 6                           The Dark Knight      joker|batman
#
#                               cast  \
# 0        [{"name": "Rob Corddry"}]
# 1      [{"name": "Anne Hathaway"}]
# 2       [{"name": "Miles Teller"}]
# 5  [{"name": "Leonardo DiCaprio"}]
# 6     [{"name": "Christian Bale"}]
#
#                                                 crew     revenue
# 0        [{"name": "Steve Pink", "job": "Director"}]    12314651
# 1    [{"name": "Garry Marshall", "job": "Director"}]    95149435
# 2   [{"name": "Damien Chazelle", "job": "Director"}]    13092000
# 5  [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6  [{"name": "Christopher Nolan", "job": "Directo...  1004558444
#
# [5 rows x 22 columns]

# %%
# Boolean Indexing
english_movies = df[df['original_language'] == 'en']
english_movies.head()
# Out:
#    id                     belongs_to_collection     budget  \
# 0   1                    Hot Tub Time Machine 2   14000000
# 1   2  The Princess Diaries 2: Royal Engagement   40000000
# 2   3                                  Whiplash    3300000
# 5   6                                 Inception  160000000
# 6   7                           The Dark Knight  185000000
#
#                                               genres  imdb_id  \
# 0                               [{"name": "Comedy"}]  2637294
# 1            [{"name": "Comedy"}, {"name": "Drama"}]   368933
# 2                                [{"name": "Drama"}]  2582802
# 5           [{"name": "Action"}, {"name": "Sci-Fi"}]  1375666
# 6  [{"name": "Action"}, {"name": "Crime"}, {"name...   468569
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 5                en                                 Inception
# 6                en                           The Dark Knight
#
#                                        overview  popularity   poster_path  \
# 0                           Time travel comedy.    6.575393  /poster1.jpg
# 1             A princess prepares for marriage.    8.248895  /poster2.jpg
# 2  A young drummer faces a ruthless instructor.   64.299990  /poster3.jpg
# 5       A thief enters dreams to steal secrets.   82.500000  /poster6.jpg
# 6                       Batman faces the Joker.   90.100000  /poster7.jpg
#
#    ... release_date runtime       spoken_languages    status  \
# 0  ...          NaT    93.0  [{"name": "English"}]  Released
# 1  ...          NaT   113.0  [{"name": "English"}]  Released
# 2  ...          NaT   105.0  [{"name": "English"}]  Released
# 5  ...          NaT   148.0  [{"name": "English"}]  Released
# 6  ...          NaT   152.0  [{"name": "English"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 5             Your mind is the scene of the crime.
# 6                                  Why so serious?
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 5                                 Inception       dream|heist
# 6                           The Dark Knight      joker|batman
#
#                               cast  \
# 0        [{"name": "Rob Corddry"}]
# 1      [{"name": "Anne Hathaway"}]
# 2       [{"name": "Miles Teller"}]
# 5  [{"name": "Leonardo DiCaprio"}]
# 6     [{"name": "Christian Bale"}]
#
#                                                 crew     revenue
# 0        [{"name": "Steve Pink", "job": "Director"}]    12314651
# 1    [{"name": "Garry Marshall", "job": "Director"}]    95149435
# 2   [{"name": "Damien Chazelle", "job": "Director"}]    13092000
# 5  [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6  [{"name": "Christopher Nolan", "job": "Directo...  1004558444
#
# [5 rows x 22 columns]

# %%
english_movies.shape
# Out:
# (18, 22)

# %%
non_english_movies = df[df['original_language'] != 'en']
non_english_movies.head()
# Out:
#     id belongs_to_collection     budget  \
# 3    4               Kahaani    1200000
# 4    5            Marine Boy          0
# 7    8              3 Idiots  550000000
# 8    9              Parasite   11400000
# 12  13      We Are the Best!          0
#
#                                         genres  imdb_id original_language  \
# 3    [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4   [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
# 7      [{"name": "Comedy"}, {"name": "Drama"}]  1187043                hi
# 8    [{"name": "Drama"}, {"name": "Thriller"}]  6751668                ko
# 12      [{"name": "Drama"}, {"name": "Music"}]  2364975                sv
#
#       original_title                                           overview  \
# 3            Kahaani  A woman searches for her missing husband in Ko...
# 4         Marine Boy        A former swimmer becomes involved in crime.
# 7           3 Idiots           Three friends navigate college and life.
# 8           Parasite  Two families become entangled in a strange sit...
# 12  We Are the Best!                      Three girls form a punk band.
#
#     popularity    poster_path  ... release_date runtime  \
# 3     3.174936   /poster4.jpg  ...          NaT   122.0
# 4     1.148070   /poster5.jpg  ...          NaT   118.0
# 7    25.300000   /poster8.jpg  ...          NaT   170.0
# 8    55.700000   /poster9.jpg  ...          NaT   132.0
# 12    3.727996  /poster13.jpg  ...          NaT   102.0
#
#                spoken_languages    status                      tagline  \
# 3   [{"name": "English|Hindi"}]  Released  Act like you own the place.
# 4          [{"name": "Korean"}]  Released  Act like you own the place.
# 7           [{"name": "Hindi"}]  Released                 All is well.
# 8          [{"name": "Korean"}]  Released  Act like you own the place.
# 12        [{"name": "Swedish"}]  Released  Act like you own the place.
#
#                title            Keywords                           cast  \
# 3            Kahaani     mystery|kolkata      [{"name": "Vidya Balan"}]
# 4         Marine Boy      CIA|conspiracy     [{"name": "Kim Kang-woo"}]
# 7           3 Idiots  college|friendship       [{"name": "Aamir Khan"}]
# 8           Parasite        family|class     [{"name": "Song Kang-ho"}]
# 12  We Are the Best!         sweden|punk  [{"name": "Mira Barkhammar"}]
#
#                                                 crew     revenue
# 3       [{"name": "Sujoy Ghosh", "job": "Director"}]    16000000
# 4    [{"name": "Yoon Jong-chan", "job": "Director"}]     3923970
# 7   [{"name": "Rajkumar Hirani", "job": "Director"}]  2000000000
# 8      [{"name": "Bong Joon Ho", "job": "Director"}]   258000000
# 12  [{"name": "Lukas Moodysson", "job": "Director"}]      180590
#
# [5 rows x 22 columns]

# %%
long_movies = df[df['runtime'] > 120]

long_movies[['title','cast']]
# Out:
#                           title                               cast
# 3                       Kahaani          [{"name": "Vidya Balan"}]
# 5                     Inception    [{"name": "Leonardo DiCaprio"}]
# 6               The Dark Knight       [{"name": "Christian Bale"}]
# 7                      3 Idiots           [{"name": "Aamir Khan"}]
# 8                      Parasite         [{"name": "Song Kang-ho"}]
# 9                  The Terminal            [{"name": "Tom Hanks"}]
# 16                 Interstellar  [{"name": "Matthew McConaughey"}]
# 17                       Dangal           [{"name": "Aamir Khan"}]
# 18            Avengers: Endgame    [{"name": "Robert Downey Jr."}]
# 19                      Titanic    [{"name": "Leonardo DiCaprio"}]
# 20                Spirited Away         [{"name": "Rumi Hiiragi"}]
# 21                The Godfather        [{"name": "Marlon Brando"}]
# 23                Mystery Movie              [{"name": "Unknown"}]
# 24                      Kantara        [{"name": "Rishab Shetty"}]
# 25                          RRR   [{"name": "N. T. Rama Rao Jr."}]
# 26  Baahubali 2: The Conclusion              [{"name": "Prabhas"}]
# 27                        Joker      [{"name": "Joaquin Phoenix"}]
# 28                   La La Land         [{"name": "Ryan Gosling"}]
# 29  Dilwale Dulhania Le Jayenge       [{"name": "Shah Rukh Khan"}]

# %% [markdown]
# ## Infact we can match conditions for mutliple columns

# %%
long_movies = df[df['runtime'] > 120]

# %%
long_movies.tail()
# Out:
#     id        belongs_to_collection     budget  \
# 25  26                          RRR  550000000
# 26  27   Bahubali 2: The Conclusion  250000000
# 27  28                        Joker   55000000
# 28  29                   La La Land   30000000
# 29  30  Dilwale Dulhania Le Jayenge   40000000
#
#                                                genres  imdb_id  \
# 25            [{"name": "Action"}, {"name": "Drama"}]  8178634
# 26            [{"name": "Action"}, {"name": "Drama"}]  4849438
# 27             [{"name": "Crime"}, {"name": "Drama"}]  7286456
# 28  [{"name": "Comedy"}, {"name": "Drama"}, {"name...  3783958
# 29           [{"name": "Drama"}, {"name": "Romance"}]   112870
#
#    original_language               original_title  \
# 25                te                          RRR
# 26                te  Baahubali 2: The Conclusion
# 27                en                        Joker
# 28                en                   La La Land
# 29                hi  Dilwale Dulhania Le Jayenge
#
#                                              overview  popularity  \
# 25   Two revolutionaries form an unlikely friendship.        60.3
# 26               A kingdom seeks answers and revenge.        52.9
# 27             A failed comedian descends into chaos.        70.9
# 28  A musician and actress pursue dreams in Los An...        35.8
# 29     A young couple challenges family expectations.        20.6
#
#       poster_path  ... release_date runtime       spoken_languages    status  \
# 25  /poster26.jpg  ...          NaT   187.0   [{"name": "Telugu"}]  Released
# 26  /poster27.jpg  ...          NaT   168.0   [{"name": "Telugu"}]  Released
# 27  /poster28.jpg  ...          NaT   122.0  [{"name": "English"}]  Released
# 28  /poster29.jpg  ...          NaT   128.0  [{"name": "English"}]  Released
# 29  /poster30.jpg  ...          NaT   181.0    [{"name": "Hindi"}]  Released
#
#                              tagline                        title  \
# 25               Rise. Roar. Revolt.                          RRR
# 26  Why did Kattappa kill Baahubali?  Baahubali 2: The Conclusion
# 27              Put on a happy face.                        Joker
# 28    Here's to the fools who dream.                   La La Land
# 29             Come... Fall in love.  Dilwale Dulhania Le Jayenge
#
#                  Keywords                              cast  \
# 25  friendship|revolution  [{"name": "N. T. Rama Rao Jr."}]
# 26            kingdom|war             [{"name": "Prabhas"}]
# 27            joker|crime     [{"name": "Joaquin Phoenix"}]
# 28      music|los angeles        [{"name": "Ryan Gosling"}]
# 29         romance|family      [{"name": "Shah Rukh Khan"}]
#
#                                                 crew     revenue
# 25  [{"name": "S. S. Rajamouli", "job": "Director"}]  1200000000
# 26  [{"name": "S. S. Rajamouli", "job": "Director"}]  1810000000
# 27    [{"name": "Todd Phillips", "job": "Director"}]  1074251311
# 28  [{"name": "Damien Chazelle", "job": "Director"}]   472000000
# 29    [{"name": "Aditya Chopra", "job": "Director"}]   120000000
#
# [5 rows x 22 columns]

# %%
(df['original_language']=='en') & (df['runtime'] > 120)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %%
long_english_movies = df[  (df['original_language']=='en') & (df['runtime'] > 120)    ]
long_english_movies.head()
# Out:
#     id belongs_to_collection     budget  \
# 5    6             Inception  160000000
# 6    7       The Dark Knight  185000000
# 9   10          The Terminal   60000000
# 16  17          Interstellar  165000000
# 18  19     Avengers: Endgame  356000000
#
#                                                genres  imdb_id  \
# 5            [{"name": "Action"}, {"name": "Sci-Fi"}]  1375666
# 6   [{"name": "Action"}, {"name": "Crime"}, {"name...   468569
# 9             [{"name": "Comedy"}, {"name": "Drama"}]   362227
# 16  [{"name": "Adventure"}, {"name": "Drama"}, {"n...   816692
# 18  [{"name": "Action"}, {"name": "Adventure"}, {"...  4154796
#
#    original_language     original_title  \
# 5                 en          Inception
# 6                 en    The Dark Knight
# 9                 en       The Terminal
# 16                en       Interstellar
# 18                en  Avengers: Endgame
#
#                                          overview  popularity    poster_path  \
# 5         A thief enters dreams to steal secrets.   82.500000   /poster6.jpg
# 6                         Batman faces the Joker.   90.100000   /poster7.jpg
# 9           A man becomes stranded in an airport.   14.092373  /poster10.jpg
# 16  Explorers travel through a wormhole in space.   75.000000  /poster17.jpg
# 18  Heroes attempt to reverse a devastating loss.   88.200000  /poster19.jpg
#
#     ... release_date runtime       spoken_languages    status  \
# 5   ...          NaT   148.0  [{"name": "English"}]  Released
# 6   ...          NaT   152.0  [{"name": "English"}]  Released
# 9   ...          NaT   128.0  [{"name": "English"}]  Released
# 16  ...          NaT   169.0  [{"name": "English"}]  Released
# 18  ...          NaT   181.0  [{"name": "English"}]  Released
#
#                                               tagline              title  \
# 5                Your mind is the scene of the crime.          Inception
# 6                                     Why so serious?    The Dark Knight
# 9                                    Life is waiting.       The Terminal
# 16  Mankind was born on Earth. It was never meant ...       Interstellar
# 18                                 Avenge the fallen.  Avengers: Endgame
#
#             Keywords                               cast  \
# 5        dream|heist    [{"name": "Leonardo DiCaprio"}]
# 6       joker|batman       [{"name": "Christian Bale"}]
# 9   airport|new york            [{"name": "Tom Hanks"}]
# 16    space|wormhole  [{"name": "Matthew McConaughey"}]
# 18  superhero|marvel    [{"name": "Robert Downey Jr."}]
#
#                                                  crew     revenue
# 5   [{"name": "Christopher Nolan", "job": "Directo...   839000000
# 6   [{"name": "Christopher Nolan", "job": "Directo...  1004558444
# 9   [{"name": "Steven Spielberg", "job": "Director"}]   219417255
# 16  [{"name": "Christopher Nolan", "job": "Directo...   701729206
# 18     [{"name": "Anthony Russo", "job": "Director"}]  2797501328
#
# [5 rows x 22 columns]

# %%
long_english_movies.shape
# Out:
# (10, 22)

# %% [markdown]
# # <u>**Next let us see how we can manipulate columns**</u>

# %%
df.shape
# Out:
# (3000, 23)

# %% [markdown]
# ## **Let's say if you wanted a new column whose values were half the movie runtime**

# %%
df['runtime']
# Out:
# 0      93.00000
# 1     113.00000
# 2     105.00000
# 3     122.00000
# 4     118.00000
# 5     148.00000
# 6     152.00000
# 7     170.00000
# 8     132.00000
# 9     128.00000
# 10    106.00000
# 11    102.00000
# 12    102.00000
# 13    120.00000
# 14     90.00000
# 15    106.00000
# 16    169.00000
# 17    161.00000
# 18    181.00000
# 19    194.00000
# 20    125.00000
# 21    175.00000
# 22      0.00000
# 23    132.62069
# 24    148.00000
# 25    187.00000
# 26    168.00000
# 27    122.00000
# 28    128.00000
# 29    181.00000
# Name: runtime, dtype: float64

# %%
df['runtime'].value_counts()
# Out:
# runtime
# 122.00000    2
# 148.00000    2
# 128.00000    2
# 106.00000    2
# 102.00000    2
# 181.00000    2
# 93.00000     1
# 113.00000    1
# 105.00000    1
# 118.00000    1
# 152.00000    1
# 170.00000    1
# 132.00000    1
# 120.00000    1
# 90.00000     1
# 169.00000    1
# 161.00000    1
# 194.00000    1
# 125.00000    1
# 175.00000    1
# 0.00000      1
# 132.62069    1
# 187.00000    1
# 168.00000    1
# Name: count, dtype: int64

# %%
df['runtime'].value_counts(normalize=True) * 100
# Out:
# runtime
# 122.00000    6.666667
# 148.00000    6.666667
# 128.00000    6.666667
# 106.00000    6.666667
# 102.00000    6.666667
# 181.00000    6.666667
# 93.00000     3.333333
# 113.00000    3.333333
# 105.00000    3.333333
# 118.00000    3.333333
# 152.00000    3.333333
# 170.00000    3.333333
# 132.00000    3.333333
# 120.00000    3.333333
# 90.00000     3.333333
# 169.00000    3.333333
# 161.00000    3.333333
# 194.00000    3.333333
# 125.00000    3.333333
# 175.00000    3.333333
# 0.00000      3.333333
# 132.62069    3.333333
# 187.00000    3.333333
# 168.00000    3.333333
# Name: proportion, dtype: float64

# %%
# Add new column which is just half the runtime
df['half_runtime'] = df['runtime'] * 0.5

# %%
df.head()
# Out:
#    id  ... half_runtime
# 0   1  ...         46.5
# 1   2  ...         56.5
# 2   3  ...         52.5
# 3   4  ...         61.0
# 4   5  ...         59.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## We can also create a new column by adding two existing columns

# %%
# Creating another new column by subtracting/adding two existing columns
df['movie_profit'] = df['revenue'] - df['budget']

# %%
df.head()
# Out:
#    id                     belongs_to_collection    budget  \
# 0   1                    Hot Tub Time Machine 2  14000000
# 1   2  The Princess Diaries 2: Royal Engagement  40000000
# 2   3                                  Whiplash   3300000
# 3   4                                   Kahaani   1200000
# 4   5                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#     poster_path  ...             spoken_languages    status  \
# 0  /poster1.jpg  ...        [{"name": "English"}]  Released
# 1  /poster2.jpg  ...        [{"name": "English"}]  Released
# 2  /poster3.jpg  ...        [{"name": "English"}]  Released
# 3  /poster4.jpg  ...  [{"name": "English|Hindi"}]  Released
# 4  /poster5.jpg  ...         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                      Act like you own the place.
# 4                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue half_runtime  \
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651         46.5
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435         56.5
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000         52.5
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000         61.0
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 24 columns]

# %% [markdown]
# ## **Next, we can also drop some columns which we want to drop**

# %%
df.head(1)
# Out:
#     belongs_to_collection    budget                genres  imdb_id  \
# 0  Hot Tub Time Machine 2  14000000  [{"name": "Comedy"}]  2637294
#
#   original_language          original_title             overview  popularity  \
# 0                en  Hot Tub Time Machine 2  Time travel comedy.    6.575393
#
#     poster_path              production_companies  ...       spoken_languages  \
# 0  /poster1.jpg  [{"name": "Paramount Pictures"}]  ...  [{"name": "English"}]
#
#      status                     tagline                   title     Keywords  \
# 0  Released  The Laws of Space and Time  Hot Tub Time Machine 2  time travel
#
#                         cast                                         crew  \
# 0  [{"name": "Rob Corddry"}]  [{"name": "Steve Pink", "job": "Director"}]
#
#     revenue half_runtime movie_profit
# 0  12314651         46.5     -1685349
#
# [1 rows x 23 columns]

# %%
# Remove column
df.drop(["half_runtime"], axis = 1, inplace=True)

# %%
# df.drop(columns=["id"],inplace=True)

# %%
df.head()
# Out:
#                       belongs_to_collection    budget  \
# 0                    Hot Tub Time Machine 2  14000000
# 1  The Princess Diaries 2: Royal Engagement  40000000
# 2                                  Whiplash   3300000
# 3                                   Kahaani   1200000
# 4                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#     poster_path                production_companies  ... runtime  \
# 0  /poster1.jpg    [{"name": "Paramount Pictures"}]  ...    93.0
# 1  /poster2.jpg  [{"name": "Walt Disney Pictures"}]  ...   113.0
# 2  /poster3.jpg            [{"name": "Bold Films"}]  ...   105.0
# 3  /poster4.jpg    [{"name": "Paramount Pictures"}]  ...   122.0
# 4  /poster5.jpg    [{"name": "Paramount Pictures"}]  ...   118.0
#
#               spoken_languages    status  \
# 0        [{"name": "English"}]  Released
# 1        [{"name": "English"}]  Released
# 2        [{"name": "English"}]  Released
# 3  [{"name": "English|Hindi"}]  Released
# 4         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                      Act like you own the place.
# 4                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast  \
# 0    [{"name": "Rob Corddry"}]
# 1  [{"name": "Anne Hathaway"}]
# 2   [{"name": "Miles Teller"}]
# 3    [{"name": "Vidya Balan"}]
# 4   [{"name": "Kim Kang-woo"}]
#
#                                                crew   revenue movie_profit
# 0       [{"name": "Steve Pink", "job": "Director"}]  12314651     -1685349
# 1   [{"name": "Garry Marshall", "job": "Director"}]  95149435     55149435
# 2  [{"name": "Damien Chazelle", "job": "Director"}]  13092000      9792000
# 3      [{"name": "Sujoy Ghosh", "job": "Director"}]  16000000     14800000
# 4   [{"name": "Yoon Jong-chan", "job": "Director"}]   3923970      3923970
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#              budget   popularity  ...  half_runtime  movie_profit
# count  3.000000e+03  3000.000000  ...   2998.000000  3.000000e+03
# mean   2.253133e+07     8.463274  ...     53.928286  4.419452e+07
# std    3.702609e+07    12.104000  ...     11.043217  1.123274e+08
# min    0.000000e+00     0.000001  ...      0.000000 -1.074474e+08
# 25%    0.000000e+00     4.018053  ...     47.000000  1.795200e+04
# 50%    8.000000e+06     7.374861  ...     52.000000  6.121122e+06
# 75%    2.900000e+07    10.890983  ...     59.000000  4.143293e+07
# max    3.800000e+08   294.337037  ...    169.000000  1.316249e+09
#
# [8 rows x 6 columns]

# %% [markdown]
# ## You can drop  multiple columns at once too.

# %%
df.drop(['poster_path'],axis=1,inplace=True)

# %%
df.drop(['crew'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#    id  ... movie_profit
# 0   1  ...     -1685349
# 1   2  ...     55149435
# 2   3  ...      9792000
# 3   4  ...     14800000
# 4   5  ...      3923970
#
# [5 rows x 23 columns]

# %% [markdown]
# ## **We can do a lot of basic operations as well**

# %%
# Find the sum of values in a column
df['budget'].sum()
# Out:
# np.int64(3028900000)

# %%
df.head()
# Out:
#                       belongs_to_collection    budget  \
# 0                    Hot Tub Time Machine 2  14000000
# 1  The Princess Diaries 2: Royal Engagement  40000000
# 2                                  Whiplash   3300000
# 3                                   Kahaani   1200000
# 4                                Marine Boy         0
#
#                                        genres  imdb_id original_language  \
# 0                        [{"name": "Comedy"}]  2637294                en
# 1     [{"name": "Comedy"}, {"name": "Drama"}]   368933                en
# 2                         [{"name": "Drama"}]  2582802                en
# 3   [{"name": "Thriller"}, {"name": "Drama"}]  1821480                hi
# 4  [{"name": "Action"}, {"name": "Thriller"}]  1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             overview  popularity  \
# 0                                Time travel comedy.    6.575393
# 1                  A princess prepares for marriage.    8.248895
# 2       A young drummer faces a ruthless instructor.   64.299990
# 3  A woman searches for her missing husband in Ko...    3.174936
# 4        A former swimmer becomes involved in crime.    1.148070
#
#                  production_companies    production_countries release_date  \
# 0    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]          NaT
# 1  [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]          NaT
# 2            [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]          NaT
# 3    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]          NaT
# 4    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]          NaT
#
#    runtime             spoken_languages    status  \
# 0     93.0        [{"name": "English"}]  Released
# 1    113.0        [{"name": "English"}]  Released
# 2    105.0        [{"name": "English"}]  Released
# 3    122.0  [{"name": "English|Hindi"}]  Released
# 4    118.0         [{"name": "Korean"}]  Released
#
#                                            tagline  \
# 0                       The Laws of Space and Time
# 1        It can take a lifetime to find true love.
# 2  The road to greatness can take you to the edge.
# 3                      Act like you own the place.
# 4                      Act like you own the place.
#
#                                       title          Keywords  \
# 0                    Hot Tub Time Machine 2       time travel
# 1  The Princess Diaries 2: Royal Engagement  princess|royalty
# 2                                  Whiplash        jazz|music
# 3                                   Kahaani   mystery|kolkata
# 4                                Marine Boy    CIA|conspiracy
#
#                           cast     revenue  movie_profit
# 0    [{"name": "Rob Corddry"}]         NaN      -1685349
# 1  [{"name": "Anne Hathaway"}]         NaN      55149435
# 2   [{"name": "Miles Teller"}]  13092000.0       9792000
# 3    [{"name": "Vidya Balan"}]  16000000.0      14800000
# 4   [{"name": "Kim Kang-woo"}]   3923970.0       3923970

# %%
# What if there is a null value
df.loc[:1,'revenue'] = np.nan

# %%
df.set_index('imdb_id', inplace=True)

# %%
df.set_index('imdb_id', inplace=True)

# %%
df.set_index("popularity",inplace=True)

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# popularity
# 6.575393                      Hot Tub Time Machine 2  14000000
# 8.248895    The Princess Diaries 2: Royal Engagement  40000000
# 64.299990                                   Whiplash   3300000
# 3.174936                                     Kahaani   1200000
# 1.148070                                  Marine Boy         0
#
#                                                 genres original_language  \
# popularity
# 6.575393                          [{"name": "Comedy"}]                en
# 8.248895       [{"name": "Comedy"}, {"name": "Drama"}]                en
# 64.299990                          [{"name": "Drama"}]                en
# 3.174936     [{"name": "Thriller"}, {"name": "Drama"}]                hi
# 1.148070    [{"name": "Action"}, {"name": "Thriller"}]                ko
#
#                                       original_title  \
# popularity
# 6.575393                      Hot Tub Time Machine 2
# 8.248895    The Princess Diaries 2: Royal Engagement
# 64.299990                                   Whiplash
# 3.174936                                     Kahaani
# 1.148070                                  Marine Boy
#
#                                                      overview  \
# popularity
# 6.575393                                  Time travel comedy.
# 8.248895                    A princess prepares for marriage.
# 64.299990        A young drummer faces a ruthless instructor.
# 3.174936    A woman searches for her missing husband in Ko...
# 1.148070          A former swimmer becomes involved in crime.
#
#                           production_companies    production_countries  \
# popularity
# 6.575393      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 8.248895    [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# 64.299990             [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# 3.174936      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]
# 1.148070      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]
#
#            release_date  runtime             spoken_languages    status  \
# popularity
# 6.575393            NaT     93.0        [{"name": "English"}]  Released
# 8.248895            NaT    113.0        [{"name": "English"}]  Released
# 64.299990           NaT    105.0        [{"name": "English"}]  Released
# 3.174936            NaT    122.0  [{"name": "English|Hindi"}]  Released
# 1.148070            NaT    118.0         [{"name": "Korean"}]  Released
#
#                                                     tagline  \
# popularity
# 6.575393                         The Laws of Space and Time
# 8.248895          It can take a lifetime to find true love.
# 64.299990   The road to greatness can take you to the edge.
# 3.174936                        Act like you own the place.
# 1.148070                        Act like you own the place.
#
#                                                title          Keywords  \
# popularity
# 6.575393                      Hot Tub Time Machine 2       time travel
# 8.248895    The Princess Diaries 2: Royal Engagement  princess|royalty
# 64.299990                                   Whiplash        jazz|music
# 3.174936                                     Kahaani   mystery|kolkata
# 1.148070                                  Marine Boy    CIA|conspiracy
#
#                                    cast     revenue  movie_profit
# popularity
# 6.575393      [{"name": "Rob Corddry"}]         NaN      -1685349
# 8.248895    [{"name": "Anne Hathaway"}]         NaN      55149435
# 64.299990    [{"name": "Miles Teller"}]  13092000.0       9792000
# 3.174936      [{"name": "Vidya Balan"}]  16000000.0      14800000
# 1.148070     [{"name": "Kim Kang-woo"}]   3923970.0       3923970

# %%
df.head()
# Out:
#                                belongs_to_collection  ...  movie_profit
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...      -1685349
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  ...      55149435
# 2                                                NaN  ...       9792000
# 3                                                NaN  ...      14800000
# 4                                                NaN  ...       3923970
#
# [5 rows x 22 columns]

# %%
df['runtime'].sum()
# Out:
# np.float64(3978.6206896551726)

# %%
print(f" The shortest movie length is {df['runtime'].min()}")
print(f" The largest movie length is {df['runtime'].max()}")
# Out:
#  The shortest movie length is 0.0
#  The largest movie length is 194.0

# %%
df[df['runtime']== 0.0]
# Out:
#            belongs_to_collection    budget  \
# popularity
# 18.2            3 Idiots Returns  80000000
#
#                                              genres original_language  \
# popularity
# 18.2        [{"name": "Comedy"}, {"name": "Drama"}]                hi
#
#               original_title                              overview  \
# popularity
# 18.2        3 Idiots Returns  Friends reunite years after college.
#
#                   production_companies    production_countries release_date  \
# popularity
# 18.2        [{"name": "Demo Studios"}]  [{"iso_3166_1": "IN"}]          NaT
#
#             runtime     spoken_languages   status  \
# popularity
# 18.2            0.0  [{"name": "Hindi"}]  Rumored
#
#                                 tagline             title Keywords  \
# popularity
# 18.2        Act like you own the place.  3 Idiots Returns  college
#
#                                 cast  revenue  movie_profit
# popularity
# 18.2        [{"name": "Aamir Khan"}]      0.0     -80000000

# %% [markdown]
# # **<code>apply()</code>** method applies a function to every row in a pandas dataframe

# %%
# Suppose we want to convert the column network to uppercase

def to_uppercase(column):
  return column.upper()

# %%
df['Capitalized_title'] = df['title'].apply(to_uppercase)

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# popularity
# 6.575393                      Hot Tub Time Machine 2  14000000
# 8.248895    The Princess Diaries 2: Royal Engagement  40000000
# 64.299990                                   Whiplash   3300000
# 3.174936                                     Kahaani   1200000
# 1.148070                                  Marine Boy         0
#
#                                                 genres original_language  \
# popularity
# 6.575393                          [{"name": "Comedy"}]                en
# 8.248895       [{"name": "Comedy"}, {"name": "Drama"}]                en
# 64.299990                          [{"name": "Drama"}]                en
# 3.174936     [{"name": "Thriller"}, {"name": "Drama"}]                hi
# 1.148070    [{"name": "Action"}, {"name": "Thriller"}]                ko
#
#                                       original_title  \
# popularity
# 6.575393                      Hot Tub Time Machine 2
# 8.248895    The Princess Diaries 2: Royal Engagement
# 64.299990                                   Whiplash
# 3.174936                                     Kahaani
# 1.148070                                  Marine Boy
#
#                                                      overview  \
# popularity
# 6.575393                                  Time travel comedy.
# 8.248895                    A princess prepares for marriage.
# 64.299990        A young drummer faces a ruthless instructor.
# 3.174936    A woman searches for her missing husband in Ko...
# 1.148070          A former swimmer becomes involved in crime.
#
#                           production_companies    production_countries  \
# popularity
# 6.575393      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 8.248895    [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# 64.299990             [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# 3.174936      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]
# 1.148070      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]
#
#            release_date  runtime             spoken_languages    status  \
# popularity
# 6.575393            NaT     93.0        [{"name": "English"}]  Released
# 8.248895            NaT    113.0        [{"name": "English"}]  Released
# 64.299990           NaT    105.0        [{"name": "English"}]  Released
# 3.174936            NaT    122.0  [{"name": "English|Hindi"}]  Released
# 1.148070            NaT    118.0         [{"name": "Korean"}]  Released
#
#                                                     tagline  \
# popularity
# 6.575393                         The Laws of Space and Time
# 8.248895          It can take a lifetime to find true love.
# 64.299990   The road to greatness can take you to the edge.
# 3.174936                        Act like you own the place.
# 1.148070                        Act like you own the place.
#
#                                                title          Keywords  \
# popularity
# 6.575393                      Hot Tub Time Machine 2       time travel
# 8.248895    The Princess Diaries 2: Royal Engagement  princess|royalty
# 64.299990                                   Whiplash        jazz|music
# 3.174936                                     Kahaani   mystery|kolkata
# 1.148070                                  Marine Boy    CIA|conspiracy
#
#                                    cast     revenue  movie_profit  \
# popularity
# 6.575393      [{"name": "Rob Corddry"}]         NaN      -1685349
# 8.248895    [{"name": "Anne Hathaway"}]         NaN      55149435
# 64.299990    [{"name": "Miles Teller"}]  13092000.0       9792000
# 3.174936      [{"name": "Vidya Balan"}]  16000000.0      14800000
# 1.148070     [{"name": "Kim Kang-woo"}]   3923970.0       3923970
#
#                                    Capitalized_title
# popularity
# 6.575393                      HOT TUB TIME MACHINE 2
# 8.248895    THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 64.299990                                   WHIPLASH
# 3.174936                                     KAHAANI
# 1.148070                                  MARINE BOY

# %% [markdown]
# ## Another way to use <code>apply()</code> involves the use of <code>lambda()</code> function.
#
# * ### A <code>lambda()</code> function is a small anonymous function.
# * ### A <code>lambda()</code> function can take any number of arguments, but can only have one expression.

# %%
def add_two_numbers(a,b):
  return a+b

# %%
x = lambda a,b : a+b
x(1,5)
# Out:
# 6

# %%
# lambda function - Row wise operation
def revised_profit(revenue, budget):
  if revenue > 0:
    new_profit = revenue - budget
  else:
    new_profit = np.nan

  return new_profit

# %%
df['new_profit'] = df.apply(lambda x: revised_profit(x['revenue'], x['budget']),axis=1)

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# popularity
# 6.575393                      Hot Tub Time Machine 2  14000000
# 8.248895    The Princess Diaries 2: Royal Engagement  40000000
# 64.299990                                   Whiplash   3300000
# 3.174936                                     Kahaani   1200000
# 1.148070                                  Marine Boy         0
#
#                                                 genres original_language  \
# popularity
# 6.575393                          [{"name": "Comedy"}]                en
# 8.248895       [{"name": "Comedy"}, {"name": "Drama"}]                en
# 64.299990                          [{"name": "Drama"}]                en
# 3.174936     [{"name": "Thriller"}, {"name": "Drama"}]                hi
# 1.148070    [{"name": "Action"}, {"name": "Thriller"}]                ko
#
#                                       original_title  \
# popularity
# 6.575393                      Hot Tub Time Machine 2
# 8.248895    The Princess Diaries 2: Royal Engagement
# 64.299990                                   Whiplash
# 3.174936                                     Kahaani
# 1.148070                                  Marine Boy
#
#                                                      overview  \
# popularity
# 6.575393                                  Time travel comedy.
# 8.248895                    A princess prepares for marriage.
# 64.299990        A young drummer faces a ruthless instructor.
# 3.174936    A woman searches for her missing husband in Ko...
# 1.148070          A former swimmer becomes involved in crime.
#
#                           production_companies    production_countries  \
# popularity
# 6.575393      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 8.248895    [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# 64.299990             [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# 3.174936      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]
# 1.148070      [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]
#
#            release_date  runtime             spoken_languages    status  \
# popularity
# 6.575393            NaT     93.0        [{"name": "English"}]  Released
# 8.248895            NaT    113.0        [{"name": "English"}]  Released
# 64.299990           NaT    105.0        [{"name": "English"}]  Released
# 3.174936            NaT    122.0  [{"name": "English|Hindi"}]  Released
# 1.148070            NaT    118.0         [{"name": "Korean"}]  Released
#
#                                                     tagline  \
# popularity
# 6.575393                         The Laws of Space and Time
# 8.248895          It can take a lifetime to find true love.
# 64.299990   The road to greatness can take you to the edge.
# 3.174936                        Act like you own the place.
# 1.148070                        Act like you own the place.
#
#                                                title          Keywords  \
# popularity
# 6.575393                      Hot Tub Time Machine 2       time travel
# 8.248895    The Princess Diaries 2: Royal Engagement  princess|royalty
# 64.299990                                   Whiplash        jazz|music
# 3.174936                                     Kahaani   mystery|kolkata
# 1.148070                                  Marine Boy    CIA|conspiracy
#
#                                    cast     revenue  movie_profit  \
# popularity
# 6.575393      [{"name": "Rob Corddry"}]         NaN      -1685349
# 8.248895    [{"name": "Anne Hathaway"}]         NaN      55149435
# 64.299990    [{"name": "Miles Teller"}]  13092000.0       9792000
# 3.174936      [{"name": "Vidya Balan"}]  16000000.0      14800000
# 1.148070     [{"name": "Kim Kang-woo"}]   3923970.0       3923970
#
#                                    Capitalized_title  new_profit
# popularity
# 6.575393                      HOT TUB TIME MACHINE 2         NaN
# 8.248895    THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT         NaN
# 64.299990                                   WHIPLASH   9792000.0
# 3.174936                                     KAHAANI  14800000.0
# 1.148070                                  MARINE BOY   3923970.0

# %% [markdown]
# ## We can also sort our dataframe by some column values in either an ascending or descending order

# %%
# Sort values in descending order
df.sort_values('runtime', ascending=False)
# Out:
#                                belongs_to_collection     budget  \
# popularity
# 78.500000                                    Titanic  200000000
# 60.300000                                        RRR  550000000
# 88.200000                          Avengers: Endgame  356000000
# 20.600000                Dilwale Dulhania Le Jayenge   40000000
# 95.300000                              The Godfather    6000000
# 25.300000                                   3 Idiots  550000000
# 75.000000                               Interstellar  165000000
# 52.900000                 Bahubali 2: The Conclusion  250000000
# 35.400000                                     Dangal   70000000
# 90.100000                            The Dark Knight  185000000
# 82.500000                                  Inception  160000000
# 42.700000                                    Kantara   16000000
# 12.500000                              Mystery Movie   25000000
# 55.700000                                   Parasite   11400000
# 35.800000                                 La La Land   30000000
# 14.092373                               The Terminal   60000000
# 72.100000                              Spirited Away   19000000
# 3.174936                                     Kahaani    1200000
# 70.900000                                      Joker   55000000
# 14.482345                    The Long Kiss Goodnight   65000000
# 1.148070                                  Marine Boy          0
# 8.248895    The Princess Diaries 2: Royal Engagement   40000000
# 7.438381                                 School Ties          0
# 10.512109                                  Abduction   35000000
# 64.299990                                   Whiplash    3300000
# 9.853270                                     Chasers          0
# 3.727996                            We Are the Best!          0
# 6.575393                      Hot Tub Time Machine 2   14000000
# 15.725542                           Along Came Polly   42000000
# 18.200000                           3 Idiots Returns   80000000
#
#                                                        genres  \
# popularity
# 78.500000            [{"name": "Drama"}, {"name": "Romance"}]
# 60.300000             [{"name": "Action"}, {"name": "Drama"}]
# 88.200000   [{"name": "Action"}, {"name": "Adventure"}, {"...
# 20.600000            [{"name": "Drama"}, {"name": "Romance"}]
# 95.300000              [{"name": "Crime"}, {"name": "Drama"}]
# 25.300000             [{"name": "Comedy"}, {"name": "Drama"}]
# 75.000000   [{"name": "Adventure"}, {"name": "Drama"}, {"n...
# 52.900000             [{"name": "Action"}, {"name": "Drama"}]
# 35.400000              [{"name": "Drama"}, {"name": "Sport"}]
# 90.100000   [{"name": "Action"}, {"name": "Crime"}, {"name...
# 82.500000            [{"name": "Action"}, {"name": "Sci-Fi"}]
# 42.700000             [{"name": "Action"}, {"name": "Drama"}]
# 12.500000             [{"name": "Comedy"}, {"name": "Drama"}]
# 55.700000           [{"name": "Drama"}, {"name": "Thriller"}]
# 35.800000   [{"name": "Comedy"}, {"name": "Drama"}, {"name...
# 14.092373             [{"name": "Comedy"}, {"name": "Drama"}]
# 72.100000        [{"name": "Animation"}, {"name": "Fantasy"}]
# 3.174936            [{"name": "Thriller"}, {"name": "Drama"}]
# 70.900000              [{"name": "Crime"}, {"name": "Drama"}]
# 14.482345             [{"name": "Crime"}, {"name": "Action"}]
# 1.148070           [{"name": "Action"}, {"name": "Thriller"}]
# 8.248895              [{"name": "Comedy"}, {"name": "Drama"}]
# 7.438381                                  [{"name": "Drama"}]
# 10.512109          [{"name": "Thriller"}, {"name": "Action"}]
# 64.299990                                 [{"name": "Drama"}]
# 9.853270            [{"name": "Comedy"}, {"name": "Romance"}]
# 3.727996               [{"name": "Drama"}, {"name": "Music"}]
# 6.575393                                 [{"name": "Comedy"}]
# 15.725542           [{"name": "Comedy"}, {"name": "Romance"}]
# 18.200000             [{"name": "Comedy"}, {"name": "Drama"}]
#
#            original_language                            original_title  \
# popularity
# 78.500000                 en                                   Titanic
# 60.300000                 te                                       RRR
# 88.200000                 en                         Avengers: Endgame
# 20.600000                 hi               Dilwale Dulhania Le Jayenge
# 95.300000                 en                             The Godfather
# 25.300000                 hi                                  3 Idiots
# 75.000000                 en                              Interstellar
# 52.900000                 te               Baahubali 2: The Conclusion
# 35.400000                 hi                                    Dangal
# 90.100000                 en                           The Dark Knight
# 82.500000                 en                                 Inception
# 42.700000                 kn                                   Kantara
# 12.500000                 en                             Mystery Movie
# 55.700000                 ko                                  Parasite
# 35.800000                 en                                La La Land
# 14.092373                 en                              The Terminal
# 72.100000                 ja                             Spirited Away
# 3.174936                  hi                                   Kahaani
# 70.900000                 en                                     Joker
# 14.482345                 en                   The Long Kiss Goodnight
# 1.148070                  ko                                Marine Boy
# 8.248895                  en  The Princess Diaries 2: Royal Engagement
# 7.438381                  en                               School Ties
# 10.512109                 en                                 Abduction
# 64.299990                 en                                  Whiplash
# 9.853270                  en                                   Chasers
# 3.727996                  sv                          We Are the Best!
# 6.575393                  en                    Hot Tub Time Machine 2
# 15.725542                 en                          Along Came Polly
# 18.200000                 hi                          3 Idiots Returns
#
#                                                      overview  \
# popularity
# 78.500000             A romance unfolds aboard a doomed ship.
# 60.300000    Two revolutionaries form an unlikely friendship.
# 88.200000       Heroes attempt to reverse a devastating loss.
# 20.600000      A young couple challenges family expectations.
# 95.300000   The aging patriarch transfers control of his e...
# 25.300000            Three friends navigate college and life.
# 75.000000       Explorers travel through a wormhole in space.
# 52.900000                A kingdom seeks answers and revenge.
# 35.400000   A father trains his daughters to become wrestl...
# 90.100000                             Batman faces the Joker.
# 82.500000             A thief enters dreams to steal secrets.
# 42.700000   A village conflict involving tradition and nat...
# 12.500000                 A mystery with incomplete metadata.
# 55.700000   Two families become entangled in a strange sit...
# 35.800000   A musician and actress pursue dreams in Los An...
# 14.092373               A man becomes stranded in an airport.
# 72.100000            A girl enters a mysterious spirit world.
# 3.174936    A woman searches for her missing husband in Ko...
# 70.900000              A failed comedian descends into chaos.
# 14.482345               A woman discovers her forgotten past.
# 1.148070          A former swimmer becomes involved in crime.
# 8.248895                    A princess prepares for marriage.
# 7.438381        A student faces prejudice at an elite school.
# 10.512109   A young man searches for the truth about his i...
# 64.299990        A young drummer faces a ruthless instructor.
# 9.853270                  Two military men escort a prisoner.
# 3.727996                        Three girls form a punk band.
# 6.575393                                  Time travel comedy.
# 15.725542               A cautious man finds unexpected love.
# 18.200000                Friends reunite years after college.
#
#                             production_companies    production_countries  \
# popularity
# 78.500000         [{"name": "20th Century Fox"}]  [{"iso_3166_1": "US"}]
# 60.300000        [{"name": "DVV Entertainment"}]  [{"iso_3166_1": "IN"}]
# 88.200000           [{"name": "Marvel Studios"}]  [{"iso_3166_1": "US"}]
# 20.600000           [{"name": "Yash Raj Films"}]  [{"iso_3166_1": "IN"}]
# 95.300000       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 25.300000       [{"name": "Vinod Chopra Films"}]  [{"iso_3166_1": "IN"}]
# 75.000000       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 52.900000         [{"name": "Arka Media Works"}]  [{"iso_3166_1": "IN"}]
# 35.400000   [{"name": "Aamir Khan Productions"}]  [{"iso_3166_1": "IN"}]
# 90.100000             [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# 82.500000             [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# 42.700000            [{"name": "Hombale Films"}]  [{"iso_3166_1": "IN"}]
# 12.500000       [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 55.700000             [{"name": "Barunson E&A"}]  [{"iso_3166_1": "KR"}]
# 35.800000                [{"name": "Lionsgate"}]  [{"iso_3166_1": "US"}]
# 14.092373           [{"name": "DreamWorks SKG"}]  [{"iso_3166_1": "US"}]
# 72.100000            [{"name": "Studio Ghibli"}]  [{"iso_3166_1": "JP"}]
# 3.174936        [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "IN"}]
# 70.900000             [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# 14.482345          [{"name": "New Line Cinema"}]  [{"iso_3166_1": "US"}]
# 1.148070        [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]
# 8.248895      [{"name": "Walt Disney Pictures"}]  [{"iso_3166_1": "US"}]
# 7.438381        [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 10.512109         [{"name": "Lions Gate Films"}]  [{"iso_3166_1": "US"}]
# 64.299990               [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
# 9.853270              [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# 3.727996               [{"name": "Memfis Film"}]  [{"iso_3166_1": "SE"}]
# 6.575393        [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "US"}]
# 15.725542             [{"name": "Jersey Films"}]  [{"iso_3166_1": "US"}]
# 18.200000             [{"name": "Demo Studios"}]  [{"iso_3166_1": "IN"}]
#
#            release_date    runtime             spoken_languages    status  \
# popularity
# 78.500000           NaT  194.00000        [{"name": "English"}]  Released
# 60.300000           NaT  187.00000         [{"name": "Telugu"}]  Released
# 88.200000           NaT  181.00000        [{"name": "English"}]  Released
# 20.600000           NaT  181.00000          [{"name": "Hindi"}]  Released
# 95.300000           NaT  175.00000        [{"name": "English"}]  Released
# 25.300000           NaT  170.00000          [{"name": "Hindi"}]  Released
# 75.000000           NaT  169.00000        [{"name": "English"}]  Released
# 52.900000           NaT  168.00000         [{"name": "Telugu"}]  Released
# 35.400000           NaT  161.00000          [{"name": "Hindi"}]  Released
# 90.100000           NaT  152.00000        [{"name": "English"}]  Released
# 82.500000           NaT  148.00000        [{"name": "English"}]  Released
# 42.700000           NaT  148.00000        [{"name": "Kannada"}]  Released
# 12.500000           NaT  132.62069        [{"name": "English"}]  Released
# 55.700000           NaT  132.00000         [{"name": "Korean"}]  Released
# 35.800000           NaT  128.00000        [{"name": "English"}]  Released
# 14.092373           NaT  128.00000        [{"name": "English"}]  Released
# 72.100000           NaT  125.00000       [{"name": "Japanese"}]  Released
# 3.174936            NaT  122.00000  [{"name": "English|Hindi"}]  Released
# 70.900000           NaT  122.00000        [{"name": "English"}]  Released
# 14.482345           NaT  120.00000        [{"name": "English"}]  Released
# 1.148070            NaT  118.00000         [{"name": "Korean"}]  Released
# 8.248895            NaT  113.00000        [{"name": "English"}]  Released
# 7.438381            NaT  106.00000        [{"name": "English"}]  Released
# 10.512109           NaT  106.00000        [{"name": "English"}]  Released
# 64.299990           NaT  105.00000        [{"name": "English"}]  Released
# 9.853270            NaT  102.00000        [{"name": "English"}]  Released
# 3.727996            NaT  102.00000        [{"name": "Swedish"}]  Released
# 6.575393            NaT   93.00000        [{"name": "English"}]  Released
# 15.725542           NaT   90.00000        [{"name": "English"}]  Released
# 18.200000           NaT    0.00000          [{"name": "Hindi"}]   Rumored
#
#                                                       tagline  \
# popularity
# 78.500000           Nothing on Earth could come between them.
# 60.300000                                 Rise. Roar. Revolt.
# 88.200000                                  Avenge the fallen.
# 20.600000                               Come... Fall in love.
# 95.300000                          An offer you can't refuse.
# 25.300000                                        All is well.
# 75.000000   Mankind was born on Earth. It was never meant ...
# 52.900000                    Why did Kattappa kill Baahubali?
# 35.400000                         Gold is pure. So is Dangal.
# 90.100000                                     Why so serious?
# 82.500000                Your mind is the scene of the crime.
# 42.700000              When tradition calls, destiny answers.
# 12.500000                         Act like you own the place.
# 55.700000                         Act like you own the place.
# 35.800000                      Here's to the fools who dream.
# 14.092373                                    Life is waiting.
# 72.100000        The tunnel led Chihiro to a mysterious town.
# 3.174936                          Act like you own the place.
# 70.900000                                Put on a happy face.
# 14.482345                What's forgotten is not always gone.
# 1.148070                          Act like you own the place.
# 8.248895            It can take a lifetime to find true love.
# 7.438381    Just because you’re accepted doesn’t mean you ...
# 10.512109           They stole his life. He's taking it back.
# 64.299990     The road to greatness can take you to the edge.
# 9.853270    It was supposed to be a routine prisoner trans...
# 3.727996                          Act like you own the place.
# 6.575393                           The Laws of Space and Time
# 15.725542   For the most cautious man on Earth, life is ab...
# 18.200000                         Act like you own the place.
#
#                                                title               Keywords  \
# popularity
# 78.500000                                    Titanic           ship|romance
# 60.300000                                        RRR  friendship|revolution
# 88.200000                          Avengers: Endgame       superhero|marvel
# 20.600000                Dilwale Dulhania Le Jayenge         romance|family
# 95.300000                              The Godfather           mafia|family
# 25.300000                                   3 Idiots     college|friendship
# 75.000000                               Interstellar         space|wormhole
# 52.900000                Baahubali 2: The Conclusion            kingdom|war
# 35.400000                                     Dangal       wrestling|family
# 90.100000                            The Dark Knight           joker|batman
# 82.500000                                  Inception            dream|heist
# 42.700000                                    Kantara      village|tradition
# 12.500000                              Mystery Movie                mystery
# 55.700000                                   Parasite           family|class
# 35.800000                                 La La Land      music|los angeles
# 14.092373                               The Terminal       airport|new york
# 72.100000                              Spirited Away           spirit|magic
# 3.174936                                     Kahaani        mystery|kolkata
# 70.900000                                      Joker            joker|crime
# 14.482345                    The Long Kiss Goodnight   assassination|memory
# 1.148070                                  Marine Boy         CIA|conspiracy
# 8.248895    The Princess Diaries 2: Royal Engagement       princess|royalty
# 7.438381                                 School Ties           school|sport
# 10.512109                                  Abduction         CIA|conspiracy
# 64.299990                                   Whiplash             jazz|music
# 9.853270                                     Chasers        prison|military
# 3.727996                            We Are the Best!            sweden|punk
# 6.575393                      Hot Tub Time Machine 2            time travel
# 15.725542                           Along Came Polly             beach|love
# 18.200000                           3 Idiots Returns                college
#
#                                          cast       revenue  movie_profit  \
# popularity
# 78.500000     [{"name": "Leonardo DiCaprio"}]  2.264743e+09    2064743305
# 60.300000    [{"name": "N. T. Rama Rao Jr."}]  1.200000e+09     650000000
# 88.200000     [{"name": "Robert Downey Jr."}]  2.797501e+09    2441501328
# 20.600000        [{"name": "Shah Rukh Khan"}]  1.200000e+08      80000000
# 95.300000         [{"name": "Marlon Brando"}]  2.500000e+08     244000000
# 25.300000            [{"name": "Aamir Khan"}]  2.000000e+09    1450000000
# 75.000000   [{"name": "Matthew McConaughey"}]  7.017292e+08     536729206
# 52.900000               [{"name": "Prabhas"}]  1.810000e+09    1560000000
# 35.400000            [{"name": "Aamir Khan"}]  3.100000e+08     240000000
# 90.100000        [{"name": "Christian Bale"}]  1.004558e+09     819558444
# 82.500000     [{"name": "Leonardo DiCaprio"}]  8.390000e+08     679000000
# 42.700000         [{"name": "Rishab Shetty"}]  4.000000e+08     384000000
# 12.500000               [{"name": "Unknown"}]  4.500000e+07      20000000
# 55.700000          [{"name": "Song Kang-ho"}]  2.580000e+08     246600000
# 35.800000          [{"name": "Ryan Gosling"}]  4.720000e+08     442000000
# 14.092373             [{"name": "Tom Hanks"}]  2.194173e+08     159417255
# 72.100000          [{"name": "Rumi Hiiragi"}]  3.958000e+08     376800000
# 3.174936            [{"name": "Vidya Balan"}]  1.600000e+07      14800000
# 70.900000       [{"name": "Joaquin Phoenix"}]  1.074251e+09    1019251311
# 14.482345           [{"name": "Geena Davis"}]  8.945676e+07      24456761
# 1.148070           [{"name": "Kim Kang-woo"}]  3.923970e+06       3923970
# 8.248895          [{"name": "Anne Hathaway"}]           NaN      55149435
# 7.438381         [{"name": "Brendan Fraser"}]  1.471507e+07      14715067
# 10.512109        [{"name": "Taylor Lautner"}]  8.208716e+07      47087155
# 64.299990          [{"name": "Miles Teller"}]  1.309200e+07       9792000
# 9.853270           [{"name": "Tom Berenger"}]  1.596687e+06       1596687
# 3.727996        [{"name": "Mira Barkhammar"}]  1.805900e+05        180590
# 6.575393            [{"name": "Rob Corddry"}]           NaN      -1685349
# 15.725542           [{"name": "Ben Stiller"}]  1.719634e+08     129963386
# 18.200000            [{"name": "Aamir Khan"}]  0.000000e+00     -80000000
#
#                                    Capitalized_title    new_profit
# popularity
# 78.500000                                    TITANIC  2.064743e+09
# 60.300000                                        RRR  6.500000e+08
# 88.200000                          AVENGERS: ENDGAME  2.441501e+09
# 20.600000                DILWALE DULHANIA LE JAYENGE  8.000000e+07
# 95.300000                              THE GODFATHER  2.440000e+08
# 25.300000                                   3 IDIOTS  1.450000e+09
# 75.000000                               INTERSTELLAR  5.367292e+08
# 52.900000                BAAHUBALI 2: THE CONCLUSION  1.560000e+09
# 35.400000                                     DANGAL  2.400000e+08
# 90.100000                            THE DARK KNIGHT  8.195584e+08
# 82.500000                                  INCEPTION  6.790000e+08
# 42.700000                                    KANTARA  3.840000e+08
# 12.500000                              MYSTERY MOVIE  2.000000e+07
# 55.700000                                   PARASITE  2.466000e+08
# 35.800000                                 LA LA LAND  4.420000e+08
# 14.092373                               THE TERMINAL  1.594173e+08
# 72.100000                              SPIRITED AWAY  3.768000e+08
# 3.174936                                     KAHAANI  1.480000e+07
# 70.900000                                      JOKER  1.019251e+09
# 14.482345                    THE LONG KISS GOODNIGHT  2.445676e+07
# 1.148070                                  MARINE BOY  3.923970e+06
# 8.248895    THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT           NaN
# 7.438381                                 SCHOOL TIES  1.471507e+07
# 10.512109                                  ABDUCTION  4.708716e+07
# 64.299990                                   WHIPLASH  9.792000e+06
# 9.853270                                     CHASERS  1.596687e+06
# 3.727996                            WE ARE THE BEST!  1.805900e+05
# 6.575393                      HOT TUB TIME MACHINE 2           NaN
# 15.725542                           ALONG CAME POLLY  1.299634e+08
# 18.200000                           3 IDIOTS RETURNS           NaN

# %%
# We can also sort by the combination of two columns
df.sort_values(['status','new_profit'], ascending=[False,True]).head()
# Out:
#            belongs_to_collection    budget  \
# popularity
# 18.200000       3 Idiots Returns  80000000
# 3.727996        We Are the Best!         0
# 9.853270                 Chasers         0
# 1.148070              Marine Boy         0
# 64.299990               Whiplash   3300000
#
#                                                 genres original_language  \
# popularity
# 18.200000      [{"name": "Comedy"}, {"name": "Drama"}]                hi
# 3.727996        [{"name": "Drama"}, {"name": "Music"}]                sv
# 9.853270     [{"name": "Comedy"}, {"name": "Romance"}]                en
# 1.148070    [{"name": "Action"}, {"name": "Thriller"}]                ko
# 64.299990                          [{"name": "Drama"}]                en
#
#               original_title                                      overview  \
# popularity
# 18.200000   3 Idiots Returns          Friends reunite years after college.
# 3.727996    We Are the Best!                 Three girls form a punk band.
# 9.853270             Chasers           Two military men escort a prisoner.
# 1.148070          Marine Boy   A former swimmer becomes involved in crime.
# 64.299990           Whiplash  A young drummer faces a ruthless instructor.
#
#                         production_companies    production_countries  \
# popularity
# 18.200000         [{"name": "Demo Studios"}]  [{"iso_3166_1": "IN"}]
# 3.727996           [{"name": "Memfis Film"}]  [{"iso_3166_1": "SE"}]
# 9.853270          [{"name": "Warner Bros."}]  [{"iso_3166_1": "US"}]
# 1.148070    [{"name": "Paramount Pictures"}]  [{"iso_3166_1": "KR"}]
# 64.299990           [{"name": "Bold Films"}]  [{"iso_3166_1": "US"}]
#
#            release_date  runtime       spoken_languages    status  \
# popularity
# 18.200000           NaT      0.0    [{"name": "Hindi"}]   Rumored
# 3.727996            NaT    102.0  [{"name": "Swedish"}]  Released
# 9.853270            NaT    102.0  [{"name": "English"}]  Released
# 1.148070            NaT    118.0   [{"name": "Korean"}]  Released
# 64.299990           NaT    105.0  [{"name": "English"}]  Released
#
#                                                       tagline  \
# popularity
# 18.200000                         Act like you own the place.
# 3.727996                          Act like you own the place.
# 9.853270    It was supposed to be a routine prisoner trans...
# 1.148070                          Act like you own the place.
# 64.299990     The road to greatness can take you to the edge.
#
#                        title         Keywords                           cast  \
# popularity
# 18.200000   3 Idiots Returns          college       [{"name": "Aamir Khan"}]
# 3.727996    We Are the Best!      sweden|punk  [{"name": "Mira Barkhammar"}]
# 9.853270             Chasers  prison|military     [{"name": "Tom Berenger"}]
# 1.148070          Marine Boy   CIA|conspiracy     [{"name": "Kim Kang-woo"}]
# 64.299990           Whiplash       jazz|music     [{"name": "Miles Teller"}]
#
#                revenue  movie_profit Capitalized_title  new_profit
# popularity
# 18.200000          0.0     -80000000  3 IDIOTS RETURNS         NaN
# 3.727996      180590.0        180590  WE ARE THE BEST!    180590.0
# 9.853270     1596687.0       1596687           CHASERS   1596687.0
# 1.148070     3923970.0       3923970        MARINE BOY   3923970.0
# 64.299990   13092000.0       9792000          WHIPLASH   9792000.0

# %%
# Find the list of unique values in a column
list(df['status'].unique())
# Out:
# ['Released', 'Rumored']

# %%
df['status'].nunique()
# Out:
# 2

# %%
list(df['original_language'].unique())
# Out:
# ['en',
#  'hi',
#  'ko',
#  'sr',
#  'fr',
#  'it',
#  'nl',
#  'zh',
#  'es',
#  'cs',
#  'ta',
#  'cn',
#  'ru',
#  'tr',
#  'ja',
#  'fa',
#  'sv',
#  'de',
#  'te',
#  'pt',
#  'mr',
#  'da',
#  'fi',
#  'el',
#  'ur',
#  'he',
#  'no',
#  'ar',
#  'nb',
#  'ro',
#  'vi',
#  'pl',
#  'hu',
#  'ml',
#  'bn',
#  'id']

# %%
# Counts the number of unique values in a column
df.original_language.nunique()
# Out:
# 7

# %%
# Give the counts of each category of a variable
df['original_language'].value_counts()
# Out:
# original_language
# en    18
# hi     5
# ko     2
# te     2
# sv     1
# ja     1
# kn     1
# Name: count, dtype: int64

# %%
# Does not make much sense to use value_counts for a numeric variable
df.runtime.value_counts()
# Out:
# 90.0     100
# 100.0     99
# 105.0     91
# 95.0      89
# 98.0      85
#         ...
# 11.0       1
# 62.0       1
# 66.0       1
# 248.0      1
# 177.0      1
# Name: runtime, Length: 139, dtype: int64
