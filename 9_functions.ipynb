# %% [markdown]
# # - python function:
#
# -For writing of the function , we have to use keyword as **def** and for output we use **return** as keyword
#
# - it is block of statement that returns the specific task
#
# - the purpose is that some commonly repeted tasks i,e you are writing same code again and again n again for differrent inputs we have to use function
#
# - we can do with function , call to reuse code

# %% [markdown]
# # function format

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - is it compulsory usage of return ?

# %% [markdown]
# No , mandatory we can also use **print()** function

# %% [markdown]
# # - print()   vs return:
#
# print() function gives Data type is  **Nonetype** while return has given same **exact same datatype**

# %%
def ravi():
    print("this is my first function")

# %%
ravi()
# Out:
# this is my first function

# %%
type(ravi())
# Out:
# this is my first function
# NoneType

# %%
def amar():
    return "this is my first function"

# %%
amar()
# Out:
# 'this is my first function'

# %%
type(amar())
# Out:
# str

# %%
"amar" + "akbar"
# Out:
# 'amarakbar'

# %%
amar()+"Anthoni"
# Out:
# 'this is my first functionAnthoni'

# %%
ravi()+"Amar"
# Out:
# this is my first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ravi()+"Amar"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
# check with list 

def ganesh():
    print([1,2,7])

# %%
ganesh()
# Out:
# [1, 2, 7]

# %%
type(ganesh())
# Out:
# [1, 2, 7]
# NoneType

# %%
def afiz():
    return [1,7,0]

# %%
afiz()
# Out:
# [1, 7, 0]

# %%
type(afiz())
# Out:
# list

# %%
x=0
y=5

while x<y:
    print("x current value ",x)
    x=x+1
    print('updated value',x)
# Out:
# x current value  0
# updated value 1
# x current value  1
# updated value 2
# x current value  2
# updated value 3
# x current value  3
# updated value 4
# x current value  4
# updated value 5

# %%
x=10
y=15

while x<y:
    print("x current value ",x)
    x=x+1
    print('updated value',x)
# Out:
# x current value  10
# updated value 11
# x current value  11
# updated value 12
# x current value  12
# updated value 13
# x current value  13
# updated value 14
# x current value  14
# updated value 15

# %%
x=20
y=39

while x<y:
    print("x current value ",x)
    x=x+1
    print('updated value',x)
# Out:
# x current value  20
# updated value 21
# x current value  21
# updated value 22
# x current value  22
# updated value 23
# x current value  23
# updated value 24
# x current value  24
# updated value 25
# x current value  25
# updated value 26
# x current value  26
# updated value 27
# x current value  27
# updated value 28
# x current value  28
# updated value 29
# x current value  29
# updated value 30
# x current value  30
# updated value 31
# x current value  31
# updated value 32
# x current value  32
# updated value 33
# x current value  33
# updated value 34
# x current value  34
# updated value 35
# x current value  35
# updated value 36
# x current value  36
# updated value 37
# x current value  37
# updated value 38
# x current value  38
# updated value 39

# %%
def find(x,y):
    while x<y:
        print("x current value ",x)
        x=x+1
        print('updated value',x)

# %%
find(0,5)
# Out:
# x current value  0
# updated value 1
# x current value  1
# updated value 2
# x current value  2
# updated value 3
# x current value  3
# updated value 4
# x current value  4
# updated value 5

# %%
find(100,104)
# Out:
# x current value  100
# updated value 101
# x current value  101
# updated value 102
# x current value  102
# updated value 103
# x current value  103
# updated value 104

# %%
find(5,7)
# Out:
# x current value  5
# updated value 6
# x current value  6
# updated value 7

# %%
a=[4,8,0,"amar",True,0.8]

b=[]

for i in a:
    if type(i)==int:
        b.append(i)

# %%
b
# Out:
# [4, 8, 0]

# %%
def inte(a):
    b=[]
    for i in a:
        if type(i)==int:
            b.append(i)
    return b

# %%
c=[1,7,8,6,.5,"amar","akbar",7,5,4]


inte(c)
# Out:
# [1, 7, 8, 6, 7, 5, 4]

# %%
d=[1,7,9,0,"anthoni","Ganesh","ravi",True]


inte(d)
# Out:
# [1, 7, 9, 0]

# %%
def palindrome(strg):
    if strg==strg[::-1]:
        print("palindrome")

    else:
        print("not a palindrome")

# %%
palindrome("madam")
# Out:
# palindrome

# %%
palindrome("amar")
# Out:
# not a palindrome

# %%
palindrome("343")
# Out:
# palindrome

# %% [markdown]
# - doc string for the function

# %%
def odd_even(num):
    """ 
    this function checks if a given number is odd or even
    input: any valid number
    output: odd/even
    created date: 11-08-2026
    """
    if type(num)==int:
        if num %2==0:
            return f"even number :{num}"
        else:
            return f" odd number :{num}"
    else:
        return "wrong input"

# %%
odd_even(8)
# Out:
# 'even number :8'

# %%
odd_even(9)
# Out:
# ' odd number :9'

# %%
odd_even("po")
# Out:
# 'wrong input'

# %%
print(odd_even.__doc__)
# Out:
#
#     this function checks if a given number is odd or even
#     input: any valid number
#     output: odd/even
#     created date: 11-08-2026

# %% [markdown]
# - benefits of using function

# %% [markdown]
# - code modularity
#
# - code readibility
#
# - code reusability

# %%
def caculate_area (length, width):
   """
    Calculate the area of a rectangle.

    Parameters:
    length (float): The length of the rectangle.
    width (float): The width of the rectangle.

    Returns:
    float: The area of the rectangle.
    """
   
   return length*width

def calculate_perimeter(length , width):
    """
    Calculate the perimeter of a rectangle.

    Parameters:
    length (float): The length of the rectangle.
    width (float): The width of the rectangle.

    Returns:
    float: The perimeter of the rectangle.
    """
    return 2*(length+width)

def print_shape (length, width):
    """
    Print the area and perimeter of a rectangle.

    Parameters:
    length (float): The length of the rectangle.
    width (float): The width of the rectangle.
    """
        

    area = caculate_area(length, width)
    perimeter = calculate_perimeter(length, width)
    print(f"Rectangle with length {length} and width {width}:")
    print(f"Area: {area}")
    print(f"Perimeter: {perimeter}")

# %%
print_shape(15,5)
# Out:
# Rectangle with length 15 and width 5:
# Area: 75
# Perimeter: 40

# %% [markdown]
# Types of arguments
#
# - default arguments:
#      - it one that assumes a default value , if no value is provided for while calling the function it works

# %%
def sum(a,b):
    return a+b

# %%
sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sum()
#
# TypeError: sum() missing 2 required positional arguments: 'a' and 'b'

# %%
sum(9,8)
# Out:
# 17

# %%
# default parameters
def sum(a=9,b=6):
    return a+b

# %%
sum()
# Out:
# 15

# %%
sum(4,5)
# Out:
# 9

# %%
sum()
# Out:
# 15

# %% [markdown]
# - positional argument
#
#      - it is an argument that passes to a function based on its position in the function

# %%
def describe_pet(animal, name, age):
    print(f"{name} is a {age}-year-old {animal}")



describe_pet("dog", "Buddy", 3)   # argument must be order
# Out:
# Buddy is a 3-year-old dog

# %%
# this is not positional argumebnt because not following parameter order while entering argument

describe_pet("Buddy", "dog", 3)
# Output: dog is a 3-year-old Buddy   ❌ wrong, but no error
# Out:
# dog is a 3-year-old Buddy

# %% [markdown]
# - keyword argument
#   - it is an argument ,it passed to function using **syntax arg=value**

# %%
def make_cake(flour,eggs,sugar,oil,milk):
    return f" mixing of {flour}gms of flour and {eggs} eggs and {sugar} gm of sugar and {oil}mls and {milk}ml of milk to prepare small cake"

# %%
make_cake(flour=200,eggs=3,sugar=100,oil=50,milk=150)  # argument you can write different order
# Out:
# ' mixing of 200gms of flour and 3 eggs and 100 gm of sugar and 50mls and 150ml of milk to prepare small cake'

# %%
make_cake(oil=50,flour=200,milk=150,eggs=3,sugar=100,)  # argument you can write different order
# Out:
# ' mixing of 200gms of flour and 3 eggs and 100 gm of sugar and 50mls and 150ml of milk to prepare small cake'

# %% [markdown]
# *args
#
# when we don't know how many arguments are going to pass into a function is called ***arg**

# %%
def calculate_area(l,b):
    return l * b



calculate_area(5,9)
# Out:
# 45

# %%
def calculate_area(l,b,h):
    return l*b*h

calculate_area(5,9,8)
# Out:
# 360

# %%
def calculate_area(*args):
    product=1
    for i in args:
        product=product*i
    return product



calculate_area(4,8)
# Out:
# 32

# %%
calculate_area(4,8,5)
# Out:
# 160

# %%
calculate_area(4,8,5,2)
# Out:
# 320

# %%
def sum_all(*args):
    return sum(args)



sum_all(1,2)
# Out:
# 3

# %%
sum_all(1,2,7,9,5)
# Out:
# 24

# %%
sum_all(1,2,3,2,9,6,5)
# Out:
# 28

# %% [markdown]
# # - **KWARGS:
#
#     - When we don't know how many keyword arguments are going to  pass into a function is called **kwargs

# %%
def ganesh(**kwargs):
    return kwargs

# %%
ganesh(b=6,a=1,c=5,d=6,e=7,f="hanesh",s=[2,4,8,9,0,1])
# Out:
# {'b': 6,
#  'a': 1,
#  'c': 5,
#  'd': 6,
#  'e': 7,
#  'f': 'hanesh',
#  's': [2, 4, 8, 9, 0, 1]}

# %%
def ganesh(**kwargs):
    return kwargs.keys()

# %%
ganesh(b=6,a=1,c=5,d=6,e=7,f="hanesh",s=[2,4,8,9,0,1])
# Out:
# dict_keys(['b', 'a', 'c', 'd', 'e', 'f', 's'])

# %%
def ganesh(**kwargs):
    return kwargs.values()

# %%
ganesh(b=6,a=1,c=5,d=6,e=7,f="hanesh",s=[2,4,8,9,0,1])
# Out:
# dict_values([6, 1, 5, 6, 7, 'hanesh', [2, 4, 8, 9, 0, 1]])

# %% [markdown]
# - lambda function:
#
#     - lambda function is anonymous function
#
#     - it doesn't have any keywords like print , return,yield
#
#    - but it has only one keyword that is lambda only
#
#    - we can use any no.of parameters with single line of code

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f1(a,b):
    return a+b

# %%
f1(4,5)
# Out:
# 9

# %%
x=lambda a,b:a+b

x(4,5)
# Out:
# 9

# %%
y=lambda *args : args

y(5,4,8,9,0)
# Out:
# (5, 4, 8, 9, 0)

# %%
abc= lambda P,T,R:P*T*R/100



abc(1000,2,10)
# Out:
# 200.0

# %% [markdown]
# - list comprehension:
#
#   - it is tool for transforming one list to another list with someconditions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x="ganesh"

# %%
for i in x:
    print(i)
# Out:
# g
# a
# n
# e
# s
# h

# %%
[ i  for i in x ]
# Out:
# ['g', 'a', 'n', 'e', 's', 'h']

# %%
for i in range(5):
    print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
[  i**2  for i in range(5)]
# Out:
# [0, 1, 4, 9, 16]

# %%
[  i**2  for i in range(5)   if i%2==0  ]
# Out:
# [0, 4, 16]

# %% [markdown]
# - Enumerate:
#
#   - The enumerate() function in Python is a built-in tool that allows you to loop through an iterable (like a list, tuple, or string) while automatically keeping track of the index of each item

# %%
a=["siri","okgoogle","Alexa"]

for i in range(len(a)):
    print(i,a[i])
# Out:
# 0 siri
# 1 okgoogle
# 2 Alexa

# %%
a=["siri","okgoogle","Alexa"]

for i in enumerate(a):
    print(i)
# Out:
# (0, 'siri')
# (1, 'okgoogle')
# (2, 'Alexa')

# %%
a=["siri","okgoogle","Alexa"]

for i,j in enumerate(a):
    print(i,j)
# Out:
# 0 siri
# 1 okgoogle
# 2 Alexa

# %%
b="amar manu"


for i ,j in enumerate(b):
    print(i,j)
# Out:
# 0 a
# 1 m
# 2 a
# 3 r
# 4
# 5 m
# 6 a
# 7 n
# 8 u

# %% [markdown]
# # iterator, itreable, generator, decarator
#
# - iterator:
#
#       - it is an object , that gives one element at atime using iter() and next() methods

# %%
range(9)
# Out:
# range(0, 9)

# %%
x=iter(range(9))

# %%
next(x)
# Out:
# 0

# %%
next(x)
# Out:
# 1

# %%
next(x)
# Out:
# 2

# %%
next(x)
# Out:
# 3

# %%
next(x)
# Out:
# 4

# %%
next(x)
# Out:
# 5

# %%
next(x)
# Out:
# 6

# %%
next(x)
# Out:
# 7

# %%
next(x)
# Out:
# 8

# %%
next(x)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 next(x)
#
# StopIteration:

# %%
y="amar"

x=iter(y)

next(x)
# Out:
# 'a'

# %%
next(x)
# Out:
# 'm'

# %%
next(x)
# Out:
# 'a'

# %%
next(x)
# Out:
# 'r'

# %%
next(x)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 next(x)
#
# StopIteration:

# %% [markdown]
# - iterable:
#
#         - it is an object ,that you can loop through using either for loop or an iterator using next() method with while loop

# %%
x="amar"

for i in x:
    print(i)
# Out:
# a
# m
# a
# r

# %%
y=[3,9,0,"ravi",8+8j]


for i in y:
    print(i)
# Out:
# 3
# 9
# 0
# ravi
# (8+8j)

# %%
range(9)
# Out:
# range(0, 9)

# %%
for i in range(9):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
numbers= [10,20,30]

it =iter(numbers)

next(it)
# Out:
# 10

# %%
next(it)
# Out:
# 20

# %%
next(it)
# Out:
# 30

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 next(it)
#
# StopIteration:

# %%
numbers= [10,20,30]

it =iter(numbers)

while True:
    try:
        print(next(it))
    except StopIteration:
        break
# Out:
# 10
# 20
# 30

# %% [markdown]
# - higher order functions:
#
# -  Map
#
# - filter
#
# -  reduce

# %%
p=[7,9,0,6,5,2,1]

max(p)
# Out:
# 9

# %%
min(p)
# Out:
# 0

# %% [markdown]
# - format of higher order of functionalities
#
#
# list(higher_order_fun( function, iterable ))

# %% [markdown]
# # MAP
#   - it applies to a function to everyelement in an iterable and it returns a new iterator

# %%
# map(function, iterable)

# %%
p=[7,9,0,6,5,2,1]

fun=lambda x: x**2 

list(map(fun, p))
# Out:
# [49, 81, 0, 36, 25, 4, 1]

# %%
def squre_num(n):
    return n**2

# %%
p=[7,9,0,6,5,2,1]

list(map(squre_num,p))
# Out:
# [49, 81, 0, 36, 25, 4, 1]

# %%
p=[7,9,0,6,5,2,1]

fun=lambda x: x**2 if x%2==0 else None

list(map(fun, p))
# Out:
# [None, None, 0, 36, None, 4, None]

# %% [markdown]
# - filter function:
#    - it select only the elements/items that satify a condition and satisfied itemss has been return  as new iterator

# %%
#list(filter(fun,iterable))

# %%
x=[4,8,9,0,5,3]


fun=lambda x:x%2==0



def check_even(z):
    if z%2==0:
        return True

# %%
list(filter(fun,x))
# Out:
# [4, 8, 0]

# %%
list(filter(check_even,x))
# Out:
# [4, 8, 0]

# %%
y=["amar","afiz","ganesh","clri"]


fun=lambda x : len(x)>5

list(filter(fun,y))
# Out:
# ['ganesh']

# %% [markdown]
# - reduce:
#
# - it combines or check all elements and gives  a single value as output

# %%
from functools import reduce

# %%
# reduce(fun,iterable)

# %%
p=[1,8,9,6,7,4,5]


print(sum(p))

print(max(p))

print(min(p))
# Out:
# 40
# 9
# 1

# %%
p=[1,8,9,6,7,4,5]

fun=lambda a,b:a+b

# %%
reduce(fun,p)
# Out:
# 40

# %%
p=[1,8,9,6,7,4,5]


def max1(x,y):
    return x if x>y else y

# %%
reduce(max1,p)
# Out:
# 9

# %% [markdown]
# - Generator :
#
#        - it is special type of function, that returns one value at atime using with Yiled keyword instead of return

# %%
def max1(x,y):
    yield x if x>y else y

# %%
reduce(max1,p)
# Out:
# <generator object max1 at 0x0000013695866440>

# %%
def numbers():
    yield 1
    yield 2
    yield 33


gen= numbers()    

next(gen)
# Out:
# 1

# %%
next(gen)
# Out:
# 2

# %%
next(gen)
# Out:
# 33

# %%
def fruits():
    yield "apple"
    yield "banana"
    yield "mango"

# %%
for i in fruits():
    print(i)
# Out:
# apple
# banana
# mango

# %% [markdown]
# # Decorator:
#
#      - it is function, we have to add extra functionality to another function without changing its original code

# %%
def deco(func):
    def fun():
        print("--starting of this function---- ")
        func()
        print("--------------------- completed the function------------------------------------")


    return fun

# %%
@deco
def hello():
    print("welcome to  clri")

# %%
hello()
# Out:
# --starting of this function----
# welcome to  clri
# --------------------- completed the function------------------------------------

# %%
def check_age(func):
    def wrapper(age):
        if age<18:
            print("vaccination not allowed")
            return 
        func(age)
    return wrapper

# %%
@check_age
def vaccination(age):
    print("vaccination completed")

# %%
vaccination(77)
# Out:
# vaccination completed

# %%
vaccination(17)
# Out:
# vaccination not allowed

# %%
import time

def time_deco(func):
    def amar():
        start_time=time.time()
        result=func()
        end_time=time.time()
        print(f"excution time {end_time - start_time:5f}")
        return result
    return amar

# %%
@time_deco
def base():
    print("start exeution")
    time.sleep(2)

base()
# Out:
# start exeution
# excution time 2.001141
