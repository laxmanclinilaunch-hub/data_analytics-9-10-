# %% [markdown]
# - Tuples:
#     - it is very similar to list and tuples are immutable i,e once created ,we can't chnage
#
#   - tuples has been constructed with ( ) and each item/ element separated commas

# %%
a=("afiz khan","ganesh","amar",1,2,9,0,True,False,3.5)

a
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
type(a)
# Out:
# tuple

# %% [markdown]
# - the () is it mandatory ?

# %%
b="afiz khan","ganesh","amar",1,2,9,0,True,False,3.5

b
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
type(b)
# Out:
# tuple

# %%
empty_str= " "

print(f"this is my empty_str:{empty_str}")

empty_list=[ ]

print(f"empty_list: {empty_list}")

empty_tuples=()

print(f"empty_tuples: {empty_tuples}")


empty_set=set()

print(f"empty_set:{empty_set}")

empty_dict={ }

print(f"empty_dict {empty_dict}")
# Out:
# this is my empty_str:
# empty_list: []
# empty_tuples: ()
# empty_set:set()
# empty_dict {}

# %% [markdown]
# - indexing: +ve index & -ve index

# %%
a=("afiz khan","ganesh","amar",1,2,9,0,True,False,3.5)


a[0]
# Out:
# 'afiz khan'

# %%
a[1]
# Out:
# 'ganesh'

# %%
a[-1]
# Out:
# 3.5

# %%
a[-3]
# Out:
# True

# %% [markdown]
# - slicing : +ve & -ve

# %%
a=("afiz khan","ganesh","amar",1,2,9,0,True,False,3.5)

a[:]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[0:]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[:10]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[0:10]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[::]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[0:10:1]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[::-1]
# Out:
# (3.5, False, True, 0, 9, 2, 1, 'amar', 'ganesh', 'afiz khan')

# %%
a[0:10:2]
# Out:
# ('afiz khan', 'amar', 2, 0, False)

# %%
a[0:10:-2]
# Out:
# ()

# %%
a[-10:]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[-10:10]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[-10:10:]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[-10:10:1]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[-10:-1:1]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False)

# %%
a[-10:-1:]
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False)

# %%
a
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a[-10:-1:3]
# Out:
# ('afiz khan', 1, 0)

# %% [markdown]
# - Methods

# %%
a
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %% [markdown]
# - index()

# %%
a.index("amar")
# Out:
# 2

# %%
a.index(1)
# Out:
# 3

# %%
a.index(2)
# Out:
# 4

# %% [markdown]
# -  count()

# %%
a
# Out:
# ('afiz khan', 'ganesh', 'amar', 1, 2, 9, 0, True, False, 3.5)

# %%
a.count('ganesh')
# Out:
# 1
