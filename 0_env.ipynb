# %% [markdown]
# # virtual env creation
#
#
# - method -1

# %% [markdown]
# Step-1
#
# conda create -n dataanalytics python=3.12 -y
#
#
# step-2
#
#
# conda activate dataanalytics

# %% [markdown]
# - Method -2

# %% [markdown]
# step-1
#
#  python -m venv venv

# %% [markdown]
# step-2
#
# venv\Scripts\activate

# %%
7
# Out:
# 7
