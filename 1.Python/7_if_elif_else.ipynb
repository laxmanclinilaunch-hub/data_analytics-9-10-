# %% [markdown]
# - if - elif- else : conditonal statements:
#    -  if statement in python allows us to tell the computer to perform alternative actions based on a certain result

# %% [markdown]
# if case1:
#
#   perform action1
#
# elif case2:
#
#    perform action2
#
#
# elif case3:
#
#
#    perform action3
#
#
# else:
#
#   perform action 4

# %%
v=1


if v<10:
    print("v is less than 10")
# Out:
# v is less than 10

# %%
v=1


if v>10:
    print("v is greater than 10")

# %%
v=1


if v>10:
    print("v is greater than 10")

else:
    print("v is less than 10")
# Out:
# v is less than 10

# %%
a=10

if a==12:
    print("a is equal to 12")
else:
    print("a is not equal to 12")
# Out:
# a is not equal to 12

# %%
a=10

if a==12:
    print("a is equal to 12")
elif a==11:
    print("a is equal to 11")
elif a==10:
    print("a is equal to 10")

else:
    print("a is not equal to 12, 11 or 10")
# Out:
# a is equal to 10

# %%
a=10

if a==12:
    print("a is equal to 12")
elif a==11:
    print("a is equal to 11")
elif a!=10:
    print("a is equal to 10")

else:
    print("a is not equal to 12, 11 or 10")
# Out:
# a is not equal to 12, 11 or 10

# %%
city="Hyderabad"

if city=="Hyderabad":
    print("welcome to Hyderabad")

elif city=="Bangalore":
    print("welcome to Bangalore")

elif city=="Chennai":
    print("welcome to Chennai")

elif city=="Mumbai":
    print("welcome to Mumbai")

elif city=="Delhi":
    print("welcome to Delhi")  

elif city=="Kolkata":
    print("welcome to Kolkata")

else:
    print("welcome to India")
# Out:
# welcome to Hyderabad

# %% [markdown]
# - input method

# %%
a=10

a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b=input("Enter a number: ")

print(b)
# Out:
# 11

# %%
type(b)
# Out:
# str

# %%
c=   int(input("Enter a number: "))


print(c)

type(c)
# Out:
# 12
# int

# %%
d=   float(input("Enter a number: "))

print(d)

type(d)
# Out:
# 5.0
# float

# %%
val=float(input("Enter  a float  number: "))
print(f"enter number :{val}")


if val>0:
    print("The number is positive")

elif val<0:
    print("The number is negative")

else:
    print("The number is zero")
# Out:
# enter number :0.0
# The number is zero

# %%
a=10

if a<10 and a==10:
    print("try do something")

else:
    print("given above condition is not satisfied")
# Out:
# given above condition is not satisfied

# %%
a=10

if a<10 or a==10:
    print("try do something")

else:
    print("given above condition is not satisfied")
# Out:
# try do something

# %%
val=float(input("Enter  a float  number: "))
print(val)

if val>=0:
    if val==0:
        print("The number is zero")
    else:
        print("The number is positive")    
else:
    print("The number is negative")
# Out:
# -1.0
# The number is negative

# %%
val=float(input("Enter  a float  number: "))
print(val)

if val>=0:
    if val>0:
        print("The number is positive")
    elif val==0:
        print("The number is zero")
        
elif val<0:
    print("The number is negative")
# Out:
# -9.0
# The number is negative

# %%
marks=int(input("Enter your marks: "))

print(marks)


if marks<600:
    print("No GRE")
    if marks<500:
        print("No TOEFL")
        if marks<400:
            print('try to do something')


    else:
        print("you got TOEFL")    

else:
    print("you got GRE congratulations")
# Out:
# 450
# No GRE
# No TOEFL

# %%
a=10
b=11
c=12
d=13

if a==9 or b==11 or c==12 or d==13:
    print("try to do something")

else:
    print("try to do something else")
# Out:
# try to do something

# %% [markdown]
# - Truthy & Falsy

# %% [markdown]
# - All values are consider "Truthy" except foloowing which are always "Falsy"

# %% [markdown]
# - None
#
# - False
#
# - 0
#
# - 0.0
#
# - empty string - " "
#
# - empty list  - [  ]
#
# - empty tuples - ( )
#
# - emptyset -set()
#
# - emptydict- { }

# %%
if False:
    print("try to do something")
else:
    print("try to do something else")
# Out:
# try to do something else

# %%
if [ ]:
    print("try to do something")
else:
    print("nothing to do")
# Out:
# nothing to do

# %%
if [123]:
    print("try to do something")
else:
    print("nothing to do")
# Out:
# try to do something

# %%
if None:
    print("try to do something")

else:
    print("nothing to say")
# Out:
# nothing to say
