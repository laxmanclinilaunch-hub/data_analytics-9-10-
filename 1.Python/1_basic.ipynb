# %% [markdown]
# - Variable

# %% [markdown]
# it is a fixed name
#
# to store the data and retrive the data (numerical, textual, boolean ....mp3, mp4, wave, images, videos etc)

# %% [markdown]
# - 1. variable name must be start with either letter or undersore

# %%
a=5

print(a)
# Out:
# 5

# %%
_a=9

print(_a)
# Out:
# 9

# %% [markdown]
# - 2. variable names can't start with numbers

# %%
1b=90

print(1b)
# Out:
#   Cell In[3], line 1
#     1b=90
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# - 3. variable name may consist of letters, numbers, underscore

# %%
b1=90

print(b1)
# Out:
# 90

# %%
_1 = 90

print(_1)
# Out:
# 90

# %%
a7_=89

a7_
# Out:
# 89

# %%
a_7=98

a_7
# Out:
# 98

# %% [markdown]
# - 4. variable names can't  be use  with python inbuild keywords

# %%
import keyword

print(keyword.kwlist)

print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
True= 5

True
# Out:
#   Cell In[10], line 1
#     True= 5
#     ^
# SyntaxError: cannot assign to True

# %%
async= 9

async
# Out:
#   Cell In[11], line 1
#     async= 9
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# - 5. python variable names ARE casesensitive (it means capital letters and small letters are different)

# %%
BD=99

print(bd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 BD=99
#       2
# ----> 3 print(bd)
#
# NameError: name 'bd' is not defined

# %%
db=90

print(DB)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 db=90
#       2
# ----> 3 print(DB)
#
# NameError: name 'DB' is not defined

# %% [markdown]
# - Arithmetic operators
#
# - + ,- , %,*,**,/,//

# %%
5+7  # addition
# Out:
# 12

# %%
12-7  # subtraction
# Out:
# 5

# %%
12*7  # multiplication
# Out:
# 84

# %%
12/7  # division
# Out:
# 1.7142857142857142

# %%
3/2  # divion  output quoeficient
# Out:
# 1.5

# %%
3//2   #floor divion  output quoeficient
# Out:
# 1

# %%
3%2  # modules gives output remainder
# Out:
# 1

# %%
print("division",3/4)


print("floor division",3//4)


print('division',4/5)

print("floor  division",4//5)
# Out:
# division 0.75
# floor division 0
# division 0.8
# floor  division 0

# %%
a=5

print(a)

print(type(a))
# Out:
# 5
# <class 'int'>

# %%
b=5.6

print(b)

print(type(b))
# Out:
# 5.6
# <class 'float'>

# %% [markdown]
# - comparision operators
#
# - , <=,>=,!=,==,<,>

# %%
a=167

b=180

a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
2==3
# Out:
# False

# %%
2==0
# Out:
# False

# %%
2 !=0
# Out:
# True

# %%
3>=2
# Out:
# True

# %%
3<=0
# Out:
# False

# %% [markdown]
# - logical operators

# %% [markdown]
# - and , or , not

# %%
x=50

print(x)
# Out:
# 50

# %%
x<6 and x < 10  # False and false =False
# Out:
# False

# %%
x>6 and x<10  #True and false = false
# Out:
# False

# %%
x>6 and  x>10  # true and true =true
# Out:
# True

# %% [markdown]
# - or

# %%
x<6 or x<10     # # False orfalse =False
# Out:
# False

# %%
x>6 or x<10#True oralse = true
# Out:
# True

# %% [markdown]
# - not

# %%
x<6 or x<10
# Out:
# False

# %%
not (x<6 or x<10 )
# Out:
# True

# %%
x>6 and  x>10
# Out:
# True

# %%
not (x>6 and  x>10)
# Out:
# False

# %% [markdown]
# - Membership operators
#    - in ,  not in

# %% [markdown]
# - it is used to test the sequence(item/element) is presented or not

# %%
y=[1,23,"laxman",'khan',"4+8j",3.5]


y
# Out:
# [1, 23, 'laxman', 'khan', '4+8j', 3.5]

# %%
print(90 in y )
# Out:
# False

# %%
print("khan" in y)
# Out:
# True

# %%
print( "khan"  not in  y )
# Out:
# False

# %% [markdown]
# - Assignment operator

# %% [markdown]
# - = , -=, +=, /=,%=,//= ,**=

# %%
x="khan"

y="ganesh"


print(x)

print(y)
# Out:
# khan
# ganesh

# %%
x,y,z = "khan" ,"ganesh","amar"


print(x)

print(y)

print(z)
# Out:
# khan
# ganesh
# amar

# %%
a=[ "khan" ,"ganesh","amar"]  # unpacking list 

p,q,r=a

print(p)
print(q)
print(r)
# Out:
# khan
# ganesh
# amar

# %% [markdown]
# -   Note
#
#       - what is difference between = and == ?
#
#     -    = it is assigment operator we have to assign the values wherre ==  comparision operator we can compare two values

# %%
balance =1000

# salary credited
balance += 5000


print("after salary:",balance)


# electricity bill paid

balance -= 899

print("salary after power bill",balance)


# interest of 10%

balance *=1.10

print("balance after interest",balance)
# Out:
# after salary: 6000
# salary after power bill 5101
# balance after interest 5611.1

# %%
a=20

b=4

a/b
# Out:
# 5.0

# %%
a=20
b=4

a/=b    # (20/4)

print(a)
# Out:
# 5.0

# %%
a=20

a//=3

print(a)
# Out:
# 6

# %%
a=5

print(a**2)
# Out:
# 25

# %%
a=5

a**=2

print(a)
# Out:
# 25
