# %% [markdown]
# # Logging:
#
# - it is a crucial aspect of any application
#
# - it is used to track the events, errors, total operational information
#
# - python built-in logging module offers a flexible framework for emting log messages from python program

# %%
import logging


logging.basicConfig(level=logging.DEBUG)


# different levels


logging.info("this is an info message of laxman")


logging.warning("this is warning to the laxman")

logging.error("this is an error message for laxman")

logging.debug("this is debug message")


logging.critical("this is critical message about laxman")
# Out:
# INFO:root:this is an info message of laxman
# WARNING:root:this is warning to the laxman
# ERROR:root:this is an error message for laxman
# DEBUG:root:this is debug message
# CRITICAL:root:this is critical message about laxman

# %% [markdown]
# # Log levels
# - info:
#    - confirmation that things are working expected

# %%
import os
import logging

# %%
LOG_DIR="loggings"


LOG_FILE_NAME="app.log"



os.makedirs(LOG_DIR,exist_ok=True)


log_path=os.path.join(LOG_DIR,LOG_FILE_NAME)

# %%
logging.basicConfig(filename=log_path,level=logging.INFO)

# %%
logging.info("I'm going to start my program")

# %% [markdown]
# # Warning :
# - An inducation that something unexpected happened or indicating someproblem in the near future
# example disk space low

# %%
logging.warning("this is first warning of my program")

# %% [markdown]
# # Error:
# Due to some serious problem , that software hasnot been able to perform some function

# %%
logging.error("this is first error of my program")

# %% [markdown]
# # Debug:
# detialed infornation , it works when only diagnosing the problems

# %%
logging.debug("this is first debug of my program")

# %% [markdown]
# # critical :
# it is very serious probelm, it effect the continues running of the problem

# %%
logging.critical("this is first critical error of my program")

# %%
def test(x,y):
    try:
        logging.info("I'm going to start my division program")
        div=x/y
        return div

    except Exception as e:
        logging.exception(e)

# %%
test(12,5)
# Out:
# 2.4

# %%
test(10,0)

# %% [markdown]
# - adding specific time_data_format

# %%
LOG_DIR="loggings"


LOG_FILE_NAME="app.log"



os.makedirs(LOG_DIR,exist_ok=True)


log_path=os.path.join(LOG_DIR,LOG_FILE_NAME)

# %%
logging.basicConfig(filename=log_path,level=logging.INFO,format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# reading of file

try:
    with open("files/sample10.txt","r")  as f:
        print(f.read())

except Exception as e:
    logging.error(e)

# %%
# reading of file

try:
    with open("files/sample.txt","r")  as f:
        print(f.read())

except Exception as e:
    logging.error(e)
# Out:
# Hello  DataAnalytics batch
# How is your classes
# Are you able to understand ?

# %%
def add(a,b):
    result = a + b
    logging.info(f"Adding {a} and {b}, result: {result}")
    return result

def subtract(a,b):
    result = a - b
    logging.info(f"Subtracting {b} from {a}, result: {result}")
    return result


def multiply(a,b):
    result = a * b
    logging.info(f"Multiplying {a} and {b}, result: {result}")
    return result    

def divide(a,b):
    if b == 0:
        logging.error("Attempted to divide by zero.")
        raise ValueError("Denominator cannot be zero.")
    result = a / b
    logging.info(f"Dividing {a} by {b}, result: {result}")
    return result

# %%
add(10, 5)

subtract(10, 5)

multiply(10, 5)

divide(10, 5)
# Out:
# 2.0
